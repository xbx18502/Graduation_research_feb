# %%
# calculate kiwifruit 's each parts' mua, mus, with equal scale enlarge
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# import tensorflow as tf
import math
# from scipy.optimize import fsolve
# from scipy.optimize import root
import scipy as scipy
from scipy.optimize import minimize
# from scipy import signal
# from scipy import linalg
# import scipy as scp
# import sympy as  syp
# from tensorflow.keras import backend as K
# from tensorflow.keras.layers import Layer
# from tensorflow.keras.models import Sequential
import os
import gc

# %%
class process_hyperspec(object):
    
    def __init__(self, path, scat):
        self.path = path
        self.scat = scat
        
    def read_data(self):
        ## Read data from txt
        data=pd.read_fwf(self.path, dtype = object, header = None)## Read data as Pandas DataFrame
        data_8 = data.loc[8,:].str[6:] ## Select data of column of wavelengths

        data_nm_dataframe =pd.read_csv(StringIO(data_8[0]))

        with open(self.path,'r',encoding='utf-8') as f:
            content = f.read()

        flag = 0
        for index in range(len(content)):##find the start point  of time and intensity data, pointer is the 'index'
            if (content[index] == '\n') and (flag != 9):
                flag = flag + 1
            elif (content[index] == '\n') and (flag == 9):
                break
            else:
                continue

        data_ns = pd.read_csv(StringIO(content[index:len(content)]), names = data_nm_dataframe.columns[0:len(set(data_nm_dataframe))]) ## Read data of time and gray 
        img_nm_ns = np.array(data_ns)    ## Transform to numpy array                                image as DataFrame; names is a 640x0 array indicates the wavelengths range
        
        self.data_frame = data_ns
        self.data_array = img_nm_ns
        
    def cal_846nm(self):
        time_total, wavelength_total = self.data_array.shape ## Generate an array contains intensity versus time data on 846nm
        data_846nm = np.zeros((time_total,), dtype = float )

        for i in range(wavelength_total):
            data_846nm = self.data_array[:,i] + data_846nm

        return data_846nm/wavelength_total
    
    def return_dataframe(self):
        
        return self.data_frame
    
    def return_array(self):
        return self.data_array

# %%
dict0 = {}
for i in range(1,100):
    dict0[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230213\\常温\\Sample'+str(i)+'.txt'
dict0[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230213\\常温\\irf00.txt'

# %%
files = os.listdir(dict0[0][0:-10])   # 读入文件夹
N = len(files)       # 统计文件夹中的文件个数
scat = [None]*N
data_480multi9 = np.zeros((N,480), dtype = float)
time_index = np.zeros((N,480))
j=0
for i in range(0,100):
    if os.path.exists(dict0[i]):
        scat[j] = process_hyperspec(dict0[i], i)
        scat[j].read_data()
        data_480multi9[j,:] = scat[j].cal_846nm()
        time_index[j] = scat[j].return_dataframe().index
        j=j+1
    else:
        pass
# ##############################################
# str0 = '['
# for i in range(N):
#     str0 = str0 +'line['+str(i)+'],'

# str0 = str0[0:-1]
# str0 = str0+']'
# ###############################################
# #########################################
# str1 = '['
# for i in range(N):
#     str1 = str1 + '\''+eval('dict0')[i][12:-4]+'\''+','

# str1 = str1+']'
# ###############################################
# line = [None]*N
# plt.figure(figsize = (5,5))
# for i in range(0,N):
#     line[i], = plt.plot(time_index[i],data_480multi9[i,:])

# plt.legend(handles=eval(str0)
#            ,labels=eval(str1),loc='best')
# plt.show()

# %%
kernel0 = np.ones((10,))
data_smooth = np.zeros((N-1,480))
for i in range(N-1):
    data_smooth[i] = np.convolve(kernel0,data_480multi9[i+1],'same')/np.sum(kernel0)
y = np.zeros((data_smooth.shape[0],data_smooth.shape[1]*2-1))
y[:,0:data_smooth.shape[1]] = data_smooth
h = np.convolve(kernel0,data_480multi9[0],'same')/np.sum(kernel0)

# %%
##########################################
fig = plt.figure(figsize = (4,4))
# plt.subplot(1,2,2)
# for i in range(1,N):
#     plt.plot(time_index[i]*1e-9,data_480multi9[i])
# plt.subplot(1,2,1)
for i in range(0,y.shape[0]):
    plt.plot(time_index[i]*1e-9,y[i,0:data_smooth.shape[1]])
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)


plt.show()

# %%
##########################################
fig = plt.figure(figsize = (4,4))

plt.plot(time_index[i]*1e-9,h)
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)


plt.show()

# %%
class calculate_miu_s1(object):
    
    def __init__(self, h, y, time_index,d):
        self.h = h
        self.y = y
        self.time = time_index
        self.d = d
        return None
    
    def transmittance(self, d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
    
    def error_cal(self, x):
        miu_a = x[0]
        #miu_a = 69
        miu_s = x[1]
         
        # k = 0.1
        # miu_a = 0.01e2
        g = 0.85
        # d = 0.38e-3
        d = self.d
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = self.time*1e-9
        # miu_s = miu_s*1e4
        intensity1 = np.zeros((T, ), dtype = float)
        for i in range(time.shape[0] ):

            intensity1[i] = calculate_miu_s1.transmittance(self, d, time[i], c, g, miu_a, miu_s)
        
        y2 = np.convolve(intensity1, self.h)
        self.intensity = intensity1
        self.y_convolved = y2
        y2 = y2/max(abs(y2))
        y3 = self.y/max(abs(self.y))
        
        return np.sum(abs(y2 - y3))
#         return time

    def get_convolved_signal(self):
        return self.y_convolved
        
    def get_x(self):
        return self.intensity

# %%
# %%capture --no-display
miu_s_get = np.zeros((y.shape[0],2))
m1=[None]*y.shape[0]
fun_value = np.zeros((y.shape[0],))
d = 50e-3
bnds = ((0, None), (0, None))
for i in range(y.shape[0]):
    m1[i] = calculate_miu_s1(h, y[i], time_index[i+1],d)
    minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
    miu_s_get[i], fun_value[i] = minu.x, minu.fun # Nelder-Mead
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\1424569783.py:9: OptimizeWarning: Unknown solver options: xtol
#   minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\2646682250.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   Z0 = 1/(miu_s_prime)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\2646682250.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\2646682250.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\2646682250.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\2646682250.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
# Optimization terminated successfully.
#          Current function value: 17.734951
#          Iterations: 79
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 24.939582
#          Iterations: 81
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 15.650376
#          Iterations: 81
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 14.122698
#          Iterations: 161
#          Function evaluations: 313
# Optimization terminated successfully.
#          Current function value: 16.254897
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 15.374163
#          Iterations: 75
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 30.789359
#          Iterations: 91
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 20.037956
#          Iterations: 85
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 25.654283
#          Iterations: 116
#          Function evaluations: 224
# Optimization terminated successfully.
#          Current function value: 18.801970
#          Iterations: 103
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: 11.113573
#          Iterations: 90
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 23.542315
#          Iterations: 94
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 13.058964
#          Iterations: 75
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 22.990066
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 14.783167
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 13.977150
#          Iterations: 77
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 17.029994
#          Iterations: 73
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 13.259822
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 15.259233
#          Iterations: 80
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 35.005267
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 16.860140
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 13.092337
#          Iterations: 101
#          Function evaluations: 191
# Optimization terminated successfully.
#          Current function value: 13.898388
#          Iterations: 92
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 21.771622
#          Iterations: 82
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 19.651761
#          Iterations: 121
#          Function evaluations: 228
# Optimization terminated successfully.
#          Current function value: 44.152350
#          Iterations: 79
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 23.380551
#          Iterations: 85
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 14.330014
#          Iterations: 109
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: 26.243228
#          Iterations: 93
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 30.313881
#          Iterations: 105
#          Function evaluations: 194
# Optimization terminated successfully.
#          Current function value: 40.907180
#          Iterations: 79
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 16.077533
#          Iterations: 82
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 29.207268
#          Iterations: 90
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 26.951093
#          Iterations: 72
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 14.382533
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 27.667827
#          Iterations: 100
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: 13.583143
#          Iterations: 87
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 14.776432
#          Iterations: 95
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 26.419226
#          Iterations: 103
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 16.127593
#          Iterations: 102
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: 11.563966
#          Iterations: 97
#          Function evaluations: 187
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18644\1424569783.py:9: RuntimeWarning: Maximum number of function evaluations has been exceeded.
#   minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# Optimization terminated successfully.
#          Current function value: 36.636216
#          Iterations: 70
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 16.895799
#          Iterations: 90
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 21.979024
#          Iterations: 85
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 14.106247
#          Iterations: 92
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 12.780135
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 13.235255
#          Iterations: 96
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 13.983560
#          Iterations: 81
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 17.850671
#          Iterations: 83
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 17.229569
#          Iterations: 75
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 15.090345
#          Iterations: 188
#          Function evaluations: 367
# Optimization terminated successfully.
#          Current function value: 12.247395
#          Iterations: 105
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 16.842982
#          Iterations: 100
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 11.977681
#          Iterations: 75
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 17.024797
#          Iterations: 87
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 19.893616
#          Iterations: 81
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 16.198266
#          Iterations: 114
#          Function evaluations: 218
# Optimization terminated successfully.
#          Current function value: 24.002550
#          Iterations: 106
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: 17.572192
#          Iterations: 83
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 32.479058
#          Iterations: 100
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 17.122133
#          Iterations: 101
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 20.314365
#          Iterations: 81
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 17.889178
#          Iterations: 95
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 14.589773
#          Iterations: 94
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 20.498793
#          Iterations: 92
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 26.401507
#          Iterations: 75
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 18.968653
#          Iterations: 94
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 19.229493
#          Iterations: 80
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 21.098692
#          Iterations: 89
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 25.388881
#          Iterations: 92
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 17.015493
#          Iterations: 103
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 15.761389
#          Iterations: 102
#          Function evaluations: 194
# Optimization terminated successfully.
#          Current function value: 21.463747
#          Iterations: 79
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 17.230469
#          Iterations: 79
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 20.625805
#          Iterations: 85
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 16.303962
#          Iterations: 102
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: 26.630365
#          Iterations: 99
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 34.280671
#          Iterations: 101
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 28.967790
#          Iterations: 92
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 39.029022
#          Iterations: 80
#          Function evaluations: 154

# %%
miu_s_get
# Out:
# array([[4.90805177e+00, 1.92153432e+03],
#        [5.85183133e+00, 1.87677449e+03],
#        [5.65043762e+00, 2.68607762e+03],
#        [5.66182316e+00, 1.68857902e+03],
#        [9.03329397e+00, 2.40493518e+03],
#        [6.88783005e+00, 2.04723501e+03],
#        [5.35976365e+00, 2.31846871e+03],
#        [5.38477229e+00, 1.83810715e+03],
#        [1.02176005e+01, 3.27976781e+03],
#        [6.87436758e+00, 2.53343879e+03],
#        [5.89864295e+00, 1.75829236e+03],
#        [7.73176317e+00, 2.60694829e+03],
#        [3.13331674e+00, 1.32766498e+03],
#        [7.50656203e+00, 2.39774249e+03],
#        [3.89368769e+00, 1.53391211e+03],
#        [4.59804950e+00, 1.99756095e+03],
#        [8.00450367e+00, 2.26496958e+03],
#        [4.82023666e+00, 1.99919203e+03],
#        [5.40623262e+00, 1.75128845e+03],
#        [4.15756184e+00, 2.30001132e+03],
#        [5.85798756e+00, 2.13618548e+03],
#        [4.93359521e+00, 1.58974211e+03],
#        [6.06853598e+00, 1.99537536e+03],
#        [6.37250902e+00, 2.09541979e+03],
#        [4.73428304e+00, 1.65043270e+03],
#        [4.79037273e+00, 2.65851137e+03],
#        [4.75379854e+00, 1.67896957e+03],
#        [6.90566375e+00, 1.95863997e+03],
#        [6.18625730e+00, 2.31800328e+03],
#        [4.75934568e+00, 2.60570050e+03],
#        [5.86708672e+00, 3.21570716e+03],
#        [4.30683091e+00, 1.97421307e+03],
#        [6.19626535e+00, 2.76603274e+03],
#        [4.51415527e+00, 1.88461465e+03],
#        [3.82143105e+00, 1.37029800e+03],
#        [3.69965248e+00, 2.16721612e+03],
#        [5.72944611e+00, 2.15097509e+03],
#        [2.35124758e+00, 1.43308389e+03],
#        [9.19827496e+00, 2.38968112e+03],
#        [5.05118782e+00, 1.60949853e+03],
#        [3.69339787e+00, 1.39225131e+03],
#        [5.24013872e+00, 1.73277899e+03],
#        [1.24628310e+01, 2.48115913e+03],
#        [8.34850242e+00, 2.01436258e+03],
#        [6.84840630e+00, 2.12270136e+03],
#        [5.62323015e+00, 1.96381069e+03],
#        [6.48162335e+00, 1.59925533e+03],
#        [5.19488584e+00, 1.64233334e+03],
#        [5.24449331e+00, 1.83211862e+03],
#        [6.81486813e+00, 1.99964860e+03],
#        [4.39713536e+00, 1.97535176e+03],
#        [4.49726700e+00, 1.75656740e+03],
#        [3.18991768e+00, 1.54660235e+03],
#        [4.89411950e+00, 1.90932339e+03],
#        [3.32198656e+00, 1.24542169e+03],
#        [5.32133666e+00, 2.29236413e+03],
#        [5.77054016e+00, 2.22111653e+03],
#        [3.64067036e+00, 1.61019577e+03],
#        [4.40087193e+00, 1.67235929e+03],
#        [4.42958055e+00, 1.89167243e+03],
#        [6.93932081e+00, 2.21586527e+03],
#        [4.32571051e+00, 1.84148568e+03],
#        [5.12078535e+00, 2.03172741e+03],
#        [5.98340211e+00, 1.93783259e+03],
#        [3.73279475e+00, 1.75483773e+03],
#        [3.61491360e+00, 1.78475414e+03],
#        [6.71804062e+00, 2.74612175e+03],
#        [6.09156489e+00, 1.83511124e+03],
#        [3.80715538e+00, 1.68430958e+03],
#        [4.41064620e+00, 1.93229210e+03],
#        [7.00861215e+00, 2.24184270e+03],
#        [3.24391332e+00, 1.74981455e+03],
#        [3.77067453e+00, 1.51109097e+03],
#        [4.76173997e+00, 2.11964032e+03],
#        [6.36851972e+00, 1.57717075e+03],
#        [5.99428127e+00, 2.13812678e+03],
#        [2.77004647e+00, 1.40884205e+03],
#        [2.82017556e+00, 1.94038496e+03],
#        [6.11797943e+00, 2.45142563e+03],
#        [4.25160588e+00, 1.78177362e+03],
#        [7.57925050e+00, 2.98746037e+03]])

# %%
np.sum(miu_s_get[:,1]/miu_s_get.shape[0])
# Out:
# 2009.3099511882758

# %%
np.sum(np.max(y,1))/y.shape[0]
# Out:
# 0.040017361111111115

# %%
# %%capture --no-display
miu = np.zeros((2,2))
miu = np.array([[83.21829252, 9789.38773514],[104.08146906,  9540.58548081]])
m2=[None]*2
d = np.array([1.3,3])*1e-3
yk0 = np.zeros((2,959))
for i in range(2):
    m2[i] = calculate_miu_s1(h[i], y[i], time_index[0],d[i])
    m2[i].error_cal([miu[i,0],miu[i,1]])
    yk0[i] = m2[i].get_convolved_signal()

# %%
print(np.sum(abs(fun_value)))
print(fun_value)
plt.figure(figsize = (18,6))
yk1 = np.zeros((2,959))

for i in range (2):
    yk1[i] = m1[i].get_convolved_signal()

for i in range(2):
    plt.subplot(1,3,i+1)
    plt.plot(y[i,:]/max(abs(y[i,:])),'-.')
    plt.plot(yk1[i]/max(abs(yk1[i])),'-.')
    plt.plot(yk0[i]/max(abs(yk0[i])),'-.')
    
plt.tight_layout(pad=1.0)
plt.show()
# Out:
# 6.232967532058431
# [2.67471907 3.55824846]
