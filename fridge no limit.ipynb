# %%
# calculate kiwifruit in fridge; 
# read process: read 99-d for each day
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# import tensorflow as tf
import math
# from scipy.optimize import fsolve
# from scipy.optimize import root
import scipy as scipy
from scipy.optimize import minimize
# from scipy import signal
# from scipy import linalg
# import scipy as scp
# import sympy as  syp
# from tensorflow.keras import backend as K
# from tensorflow.keras.layers import Layer
# from tensorflow.keras.models import Sequential
import os
import gc
import random

# %%
class process_hyperspec(object):
    
    def __init__(self, path, scat):
        self.path = path
        self.scat = scat
        
    def read_data(self):
        ## Read data from txt
        data=pd.read_fwf(self.path, dtype = object, header = None)## Read data as Pandas DataFrame
        data_8 = data.loc[8,:].str[6:] ## Select data of column of wavelengths

        data_nm_dataframe =pd.read_csv(StringIO(data_8[0]))

        with open(self.path,'r',encoding='utf-8') as f:
            content = f.read()

        flag = 0
        for index in range(len(content)):##find the start point  of time and intensity data, pointer is the 'index'
            if (content[index] == '\n') and (flag != 9):
                flag = flag + 1
            elif (content[index] == '\n') and (flag == 9):
                break
            else:
                continue

        data_ns = pd.read_csv(StringIO(content[index:len(content)]), names = data_nm_dataframe.columns[0:len(set(data_nm_dataframe))]) ## Read data of time and gray 
        img_nm_ns = np.array(data_ns)    ## Transform to numpy array                                image as DataFrame; names is a 640x0 array indicates the wavelengths range
        
        self.data_frame = data_ns
        self.data_array = img_nm_ns
        
    def cal_846nm(self):
        time_total, wavelength_total = self.data_array.shape ## Generate an array contains intensity versus time data on 846nm
        data_846nm = np.zeros((time_total,), dtype = float )

        for i in range(wavelength_total):
            data_846nm = self.data_array[:,i] + data_846nm

        return data_846nm/wavelength_total
    
    def return_dataframe(self):
        
        return self.data_frame
    
    def return_array(self):
        return self.data_array

# %%
dict0 = {}
for i in range(1,100):
    dict0[i] = '.\\20230210\\冷库\\Sample'+str(i)+'.txt'
dict0[0] = '.\\20230210\\冷库\\irf00.txt'

dict1 = {}
for i in range(1,100):
    dict1[i] = '.\\20230217\\冷库\\Sample'+str(i)+'.txt'
dict1[0] = '.\\20230217\\冷库\\irf00.txt'

dict2 = {}
for i in range(1,100):
    dict2[i] = '.\\20230224\\冷库\\Sample'+str(i)+'.txt'
dict2[0] = '.\\20230224\\冷库\\irf00.txt'

dict3 = {}
for i in range(1,100):
    dict3[i] = '.\\20230303\\冷库\\Sample'+str(i)+'.txt'
dict3[0] = '.\\20230303\\冷库\\irf00.txt'

dict4 = {}
for i in range(1,100):
    dict4[i] = '.\\20230310\\冷库\\Sample'+str(i)+'.txt'
dict4[0] = '.\\20230310\\冷库\\irf00.txt'

dict5 = {}
for i in range(1,100):
    dict5[i] = '.\\20230317\\冷库\\Sample'+str(i)+'.txt'
dict5[0] = '.\\20230317\\冷库\\irf00.txt'

dict6 = {}
for i in range(1,100):
    dict6[i] = '.\\20230324\\冷库\\Sample'+str(i)+'.txt'
dict6[0] = '.\\20230324\\冷库\\irf00.txt'

dictn = [dict0,dict1,dict2,dict3,dict4,dict5,dict6]

# %%
class analyze(object):
    def __init__(self):

        return
    def read_radius(self):
        data1 = pd.read_excel('./kiwi_data.xlsx',sheet_name=1,header=None)
        data2 = np.array(data1)
        return data2[:,1]

    def read_everyday(self,dict0,radius):    
        files = os.listdir(dict0[0][0:-10])   # 读入文件夹
        N = len(files)       # 统计文件夹中的文件个数
        scat = [None]*N
        data_480multi9 = np.zeros((N,480), dtype = float)
        time_index = np.zeros((N,480))
        radius0 = np.zeros((N-1,))
        j=0
        for i in range(0,100):
            if os.path.exists(dict0[i]):
                scat[j] = process_hyperspec(dict0[i], i)
                scat[j].read_data()
                data_480multi9[j,:] = scat[j].cal_846nm()
                time_index[j] = scat[j].return_dataframe().index
                if(i!=0):
                    radius0[j-1] = radius[i-1]
                j=j+1
            else:
                pass
        return data_480multi9,time_index,N,radius0

    def generate_h_y(self,data_480multi9,N):
        kernel0 = np.ones((10,))
        data_smooth = np.zeros((N-1,480))
        for i in range(N-1):
            data_smooth[i] = np.convolve(kernel0,data_480multi9[i+1],'same')/np.sum(kernel0)
        y = np.zeros((data_smooth.shape[0],data_smooth.shape[1]*2-1))
        y[:,0:data_smooth.shape[1]] = data_smooth
        h = np.convolve(kernel0,data_480multi9[0],'same')/np.sum(kernel0)
        return h,y

# %%
ana = analyze()
H = []
Y = []
TIME = []
R = []
AMOUNT_EXP = len(dictn)
for i in range(AMOUNT_EXP):
    radius = ana.read_radius()
    data_480multi9,time_index,N,radius0 = ana.read_everyday(dictn[i],radius)
    h,y = ana.generate_h_y(data_480multi9,N)
    H.append(h)
    Y.append(y)
    TIME.append(time_index)
    R.append(radius0)

# %%
##########################################
fig = plt.figure(figsize = (8,8))
fig.suptitle('raw data of all fridge sample')
for i in range(AMOUNT_EXP):
    plt.subplot(3,4,i+1)
    plt.title('week'+str(i))
    for j in range(Y[i].shape[0]):
        plt.plot(time_index[i]*1e-9,Y[i][j,0:data_480multi9.shape[1]])
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)

plt.show()

# %%
##########################################
fig = plt.figure(figsize = (4,4))

plt.plot(time_index[i]*1e-9,h)
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)


plt.show()

# %%
class calculate_miu_s1(object):
    
    def __init__(self, h, y, time_index,d):
        self.h = h
        self.y = y
        self.time = time_index
        self.d = d
        return None
    
    def transmittance(self, d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
    
    def error_cal(self, x):
        miu_a = x[0]
        #miu_a = 69
        miu_s = x[1]
         
        # k = 0.1
        # miu_a = 0.01e2
        g = 0.85
        # d = 0.38e-3
        d = self.d
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = self.time*1e-9
        # miu_s = miu_s*1e4
        intensity1 = np.zeros((T, ), dtype = float)
        for i in range(time.shape[0] ):

            intensity1[i] = calculate_miu_s1.transmittance(self, d, time[i], c, g, miu_a, miu_s)
        
        y2 = np.convolve(intensity1, self.h)
        self.intensity = intensity1
        self.y_convolved = y2
        y2 = y2/max(abs(y2))
        y3 = self.y/max(abs(self.y))
        
        return np.sum(abs(y2 - y3))
#         return time

    def get_convolved_signal(self):
        return self.y_convolved
        
    def get_x(self):
        return self.intensity

# %%
class call_cal(object):
    def __init__(self):
        return
    def call_cal(self,h,y,time_index,radius):
            # %%capture --no-display
            miu_s_get = np.zeros((y.shape[0],2))
            m1=[None]*y.shape[0]
            fun_value = np.zeros((y.shape[0],))
            bnds = ((0,None), (0, None))
            convolved = np.zeros((y.shape[0],959))
            for i in range(y.shape[0]):
                d = radius[i]*1e-3
                m1[i] = calculate_miu_s1(h, y[i], time_index[i+1],d)
                try:
                    minu = minimize(m1[i].error_cal, x0 = [0.065e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
                    miu_s_get[i], fun_value[i] = minu.x, minu.fun # Nelder-Mead
                    convolved[i] = m1[i].get_convolved_signal()
                except:
                    print("one error occured, on the "+str(i)+"th kiwi")
            return miu_s_get,convolved

    def call_(self,H,Y,TIME,R,AMOUNT_EXP):
        miu_as = []
        convolved_sig = []
        for i in range(AMOUNT_EXP):
            miu_s_get, convolved = self.call_cal(H[i],Y[i],TIME[i],R[i])
            miu_as.append(miu_s_get)
            convolved_sig.append(convolved)
        return miu_as,convolved_sig

# %%
call = call_cal()
miu_as,convolved = call.call_(H,Y,TIME,R,AMOUNT_EXP)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3640020254.py:15: OptimizeWarning: Unknown solver options: xtol
#   minu = minimize(m1[i].error_cal, x0 = [0.065e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3771615487.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   Z0 = 1/(miu_s_prime)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3771615487.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3771615487.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3771615487.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3771615487.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
# Optimization terminated successfully.
#          Current function value: 34.287273
#          Iterations: 79
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 28.730101
#          Iterations: 83
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 22.509596
#          Iterations: 79
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 20.920046
#          Iterations: 88
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 36.682885
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 38.785926
#          Iterations: 72
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 16.739914
#          Iterations: 89
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 14.086350
#          Iterations: 79
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 19.061132
#          Iterations: 172
#          Function evaluations: 340
# Optimization terminated successfully.
#          Current function value: 29.843502
#          Iterations: 67
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 13.311754
#          Iterations: 98
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 20.152595
#          Iterations: 91
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 20.653311
#          Iterations: 147
#          Function evaluations: 289
# Optimization terminated successfully.
#          Current function value: 20.468092
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 29.741331
#          Iterations: 91
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 25.067860
#          Iterations: 74
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 18.022434
#          Iterations: 81
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 24.043954
#          Iterations: 83
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 14.403624
#          Iterations: 92
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 20.567993
#          Iterations: 82
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 24.658301
#          Iterations: 95
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 30.803497
#          Iterations: 87
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 40.724670
#          Iterations: 83
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 17.493306
#          Iterations: 74
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 18.972874
#          Iterations: 83
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 32.470206
#          Iterations: 72
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 21.981957
#          Iterations: 73
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 12.761243
#          Iterations: 85
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 11.904883
#          Iterations: 109
#          Function evaluations: 207
# Optimization terminated successfully.
#          Current function value: 15.707120
#          Iterations: 76
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 17.333213
#          Iterations: 83
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 17.873020
#          Iterations: 83
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 21.987607
#          Iterations: 99
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 15.614372
#          Iterations: 90
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 34.724088
#          Iterations: 77
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 24.255332
#          Iterations: 85
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 11.567319
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 29.628506
#          Iterations: 78
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 19.723070
#          Iterations: 105
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 23.966125
#          Iterations: 74
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 17.796905
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 22.941428
#          Iterations: 77
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 15.943912
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 24.357879
#          Iterations: 71
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 18.886037
#          Iterations: 90
#          Function evaluations: 170
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_15964/3640020254.py:15: RuntimeWarning: Maximum number of function evaluations has been exceeded.
#   minu = minimize(m1[i].error_cal, x0 = [0.065e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# Optimization terminated successfully.
#          Current function value: 23.707167
#          Iterations: 121
#          Function evaluations: 229
# Optimization terminated successfully.
#          Current function value: 18.011407
#          Iterations: 97
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 26.650692
#          Iterations: 80
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 25.200771
#          Iterations: 90
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 20.629802
#          Iterations: 82
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 15.468311
#          Iterations: 92
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 30.258792
#          Iterations: 78
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 27.230620
#          Iterations: 83
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 32.502675
#          Iterations: 94
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 18.110483
#          Iterations: 86
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 29.811718
#          Iterations: 101
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 35.042737
#          Iterations: 133
#          Function evaluations: 252
# Optimization terminated successfully.
#          Current function value: 20.659206
#          Iterations: 71
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 12.447386
#          Iterations: 87
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 19.921317
#          Iterations: 99
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 16.023156
#          Iterations: 77
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 20.317755
#          Iterations: 86
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 12.367385
#          Iterations: 87
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 13.355098
#          Iterations: 87
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 28.601686
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 19.237150
#          Iterations: 98
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 29.691458
#          Iterations: 84
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 22.477770
#          Iterations: 108
#          Function evaluations: 206
# Optimization terminated successfully.
#          Current function value: 15.400785
#          Iterations: 126
#          Function evaluations: 233
# Optimization terminated successfully.
#          Current function value: 29.714258
#          Iterations: 104
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: 42.706898
#          Iterations: 92
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 17.605411
#          Iterations: 97
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value:
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 9.165712
#          Iterations: 88
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 11.942243
#          Iterations: 93
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 18.521143
#          Iterations: 85
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 14.375888
#          Iterations: 89
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 17.292220
#          Iterations: 93
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 19.252867
#          Iterations: 81
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 28.791737
#          Iterations: 90
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 17.477258
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 14.385143
#          Iterations: 116
#          Function evaluations: 223
# Optimization terminated successfully.
#          Current function value: 24.241588
#          Iterations: 96
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 13.058637
#          Iterations: 84
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 18.748712
#          Iterations: 127
#          Function evaluations: 246
# Optimization terminated successfully.
#          Current function value: 25.566203
#          Iterations: 92
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 36.537436
#          Iterations: 78
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 17.406467
#          Iterations: 93
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 21.432827
#          Iterations: 88
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 19.619769
#          Iterations: 91
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 28.967947
#          Iterations: 79
#          Function evaluations: 151
# ...
# Optimization terminated successfully.
#          Current function value: 25.632491
#          Iterations: 87
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 26.932481
#          Iterations: 93
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 19.458981
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 12.686207
#          Iterations: 87
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 18.037490
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 24.208777
#          Iterations: 89
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 33.287607
#          Iterations: 70
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 15.873003
#          Iterations: 104
#          Function evaluations: 194
# Optimization terminated successfully.
#          Current function value: 17.632920
#          Iterations: 78
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 26.751972
#          Iterations: 86
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 17.295979
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 10.600108
#          Iterations: 86
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 19.579803
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 10.727420
#          Iterations: 97
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 16.067151
#          Iterations: 80
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 12.116546
#          Iterations: 106
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 10.613384
#          Iterations: 97
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 32.147304
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 17.304496
#          Iterations: 94
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 31.242851
#          Iterations: 77
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 16.659624
#          Iterations: 90
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 14.217670
#          Iterations: 111
#          Function evaluations: 213
# Optimization terminated successfully.
#          Current function value: 12.601259
#          Iterations: 82
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 17.366123
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 25.678744
#          Iterations: 82
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 14.300729
#          Iterations: 69
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 20.074730
#          Iterations: 78
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 25.767599
#          Iterations: 83
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 21.461302
#          Iterations: 116
#          Function evaluations: 222
# Optimization terminated successfully.
#          Current function value: 13.845230
#          Iterations: 86
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 23.274701
#          Iterations: 74
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 12.841460
#          Iterations: 91
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 14.175563
#          Iterations: 89
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 12.125941
#          Iterations: 85
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 21.003779
#          Iterations: 83
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 26.097919
#          Iterations: 87
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 19.685203
#          Iterations: 82
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 16.378824
#          Iterations: 91
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 17.301567
#          Iterations: 94
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 26.532625
#          Iterations: 89
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 40.604832
#          Iterations: 89
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 15.408105
#          Iterations: 96
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 13.013017
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 18.776033
#          Iterations: 80
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 11.669939
#          Iterations: 95
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 26.006289
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 22.301412
#          Iterations: 88
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 19.006787
#          Iterations: 62
#          Function evaluations: 121
# Optimization terminated successfully.
#          Current function value: 31.407417
#          Iterations: 152
#          Function evaluations: 292
# Optimization terminated successfully.
#          Current function value: 20.387237
#          Iterations: 93
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 20.208655
#          Iterations: 90
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 23.311949
#          Iterations: 105
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 16.027375
#          Iterations: 88
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 22.421566
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 21.229005
#          Iterations: 84
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 32.136932
#          Iterations: 88
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 20.245223
#          Iterations: 93
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 21.418654
#          Iterations: 90
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 22.715858
#          Iterations: 79
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 28.935230
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 26.303140
#          Iterations: 132
#          Function evaluations: 247
# Optimization terminated successfully.
#          Current function value: 9.810901
#          Iterations: 108
#          Function evaluations: 206
# Optimization terminated successfully.
#          Current function value: 11.174169
#          Iterations: 97
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 20.692457
#          Iterations: 93
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 19.642850
#          Iterations: 105
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: 13.940707
#          Iterations: 85
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 18.048073
#          Iterations: 90
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 18.548265
#          Iterations: 86
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 36.135568
#          Iterations: 75
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 19.361125
#          Iterations: 95
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 11.909733
#          Iterations: 87
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 25.718336
#          Iterations: 91
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 12.751248
#          Iterations: 86
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 22.952110
#          Iterations: 96
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 15.994650
#          Iterations: 86
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 33.583844
#          Iterations: 67
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 14.064111
#          Iterations: 97
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 25.322197
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 14.802102
#          Iterations: 97
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 19.487455
#          Iterations: 98
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 24.759164
#          Iterations: 107
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: 19.601884
#          Iterations: 126
#          Function evaluations: 244
# Optimization terminated successfully.
#          Current function value: 24.033635
#          Iterations: 82
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 26.069643
#          Iterations: 84
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 22.877960
#          Iterations: 103
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 14.889889
#          Iterations: 81
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 24.810748
#          Iterations: 91
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 20.885174
#          Iterations: 89
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 27.032436
#          Iterations: 89
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 12.494125
#          Iterations: 83
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 15.085766
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 23.754352
#          Iterations: 83
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 18.392253
#          Iterations: 88
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 10.604483
#          Iterations: 95
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 25.752636
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 10.931950
#          Iterations: 83
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 23.561915
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 11.260863
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 9.976817
#          Iterations: 85
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 25.159500
#          Iterations: 115
#          Function evaluations: 218
# Optimization terminated successfully.
#          Current function value: 13.053923
#          Iterations: 89
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 12.153523
#          Iterations: 79
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 17.610919
#          Iterations: 122
#          Function evaluations: 229
# Optimization terminated successfully.
#          Current function value: 18.466349
#          Iterations: 100
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: 16.882300
#          Iterations: 89
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 18.584120
#          Iterations: 97
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 53.137309
#          Iterations: 87
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 16.069563
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 14.164032
#          Iterations: 103
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: 24.085061
#          Iterations: 73
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 23.325733
#          Iterations: 74
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 14.288292
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 14.717470
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 20.080094
#          Iterations: 86
#          Function evaluations: 160

# %%
# def mean(x):
#     sum= np.sum(x)
#     i=0
#     for i in range(x.shape[0]):
#         if(x[i]!=0): i=i+1
#     return sum/i

# avg_miu = [None]*AMOUNT_EXP
# for i in range(AMOUNT_EXP):
#     avg_miu[i] = np.sum(miu_as[i],axis=0)/Y[i].shape[0]
avg_miu = [None]*AMOUNT_EXP
for i in range(AMOUNT_EXP):
    avg_0 = np.mean(miu_as[i][:,0])
    avg_1 = np.mean(miu_as[i][:,1])
    avg_i = np.array([avg_0,avg_1])
    avg_miu[i] = avg_i

# %%
mid_miu = [None]*AMOUNT_EXP
for i in range(AMOUNT_EXP):
    avg_0 = np.median(miu_as[i][:,0])
    avg_1 = np.median(miu_as[i][:,1])
    avg_i = np.array([avg_0,avg_1])
    mid_miu[i] = avg_i

# %%
avg_miu
# Out:
# [array([   6.60920134, 2701.33413833]),
#  array([   6.75070774, 2458.92624543]),
#  array([   5.6312261 , 2406.78361319]),
#  array([   5.95073954, 2480.98701774]),
#  array([   5.67670539, 2260.39988703]),
#  array([   6.17050841, 2361.48144916]),
#  array([   5.76195632, 2231.40864475])]

# %%
mid_miu
# Out:
# [array([   6.65886489, 2692.82563126]),
#  array([   6.87342081, 2458.3244565 ]),
#  array([   5.460476  , 2319.71676591]),
#  array([   6.04781889, 2403.74091193]),
#  array([   5.91794212, 2206.50779882]),
#  array([   6.04475517, 2363.60777726]),
#  array([   5.63908723, 2192.18416195])]

# %%
weeks_ = np.array([0,1,2,3,4,5,6,7])
mua = []
for i in range(len(avg_miu)):
    mua.append(avg_miu[i][0])
mus = []
for i in range(len(avg_miu)):
    mus.append(avg_miu[i][1])
fig = plt.figure(figsize = (8,4))
fig.suptitle('mua&mus for kiwi in fridge')
ax0=plt.subplot(1,2,1)
ax0.set_title('mua')
ax0.set_xticks(weeks_[0:AMOUNT_EXP])
ax0.set_xlabel('week')
ax0.set_ylabel('/m')
ax0.plot(weeks_[0:AMOUNT_EXP],mua)
ax1=plt.subplot(1,2,2)
ax1.set_title('mus')
ax1.set_xticks(weeks_[0:AMOUNT_EXP])
ax1.set_xlabel('week')
ax1.set_ylabel('/m')
ax1.plot(weeks_[0:AMOUNT_EXP],mus)
plt.show()

# %%
weeks_ = np.array([0,1,2,3,4,5,6,7])
mua = []
for i in range(len(mid_miu)):
    mua.append(mid_miu[i][0])
mus = []
for i in range(len(mid_miu)):
    mus.append(mid_miu[i][1])
plt.figure(figsize = (8,4))
ax0=plt.subplot(1,2,1)
ax0.set_title('mua')
ax0.set_xticks(weeks_[0:AMOUNT_EXP])
ax0.set_xlabel('week')
ax0.set_ylabel('/m')
ax0.plot(weeks_[0:AMOUNT_EXP],mua)
ax1=plt.subplot(1,2,2)
ax1.set_title('mus')
ax1.set_xticks(weeks_[0:AMOUNT_EXP])
ax1.set_xlabel('week')
ax1.set_ylabel('/m')
ax1.plot(weeks_[0:AMOUNT_EXP],mus)
plt.show()

# %%
AMOUNT_i = 3
AMOUNT_j = 3
i_rand = random.sample(range(0,len(Y)), AMOUNT_i)
j_rand = random.sample(range(0,len(Y[0])), AMOUNT_j)
plt.figure(figsize = (6,6))
for i in range(AMOUNT_i):
    for j in range(AMOUNT_j):
        plt.subplot(3,3,i*AMOUNT_j+j+1)
        plt.plot(convolved[i_rand[i]][j_rand[j]]/1.4e11)
        plt.plot(Y[i_rand[i]][j_rand[j]])
    
plt.tight_layout(pad=1.0)
plt.show()
