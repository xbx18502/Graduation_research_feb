# %%
# calculate kiwifruit in normal temparature;
# read process: read 99-d for each day
# calculate : try to limit the range of mua to make mus more linear
# based on "calculate_muamus_sa3.3.ipynb"
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# import tensorflow as tf
import math
# from scipy.optimize import fsolve
# from scipy.optimize import root
import scipy as scipy
from scipy.optimize import minimize
# from scipy import signal
# from scipy import linalg
# import scipy as scp
# import sympy as  syp
# from tensorflow.keras import backend as K
# from tensorflow.keras.layers import Layer
# from tensorflow.keras.models import Sequential
import os
import gc
import random

# %%
class process_hyperspec(object):
    
    def __init__(self, path, scat):
        self.path = path
        self.scat = scat
        
    def read_data(self):
        ## Read data from txt
        data=pd.read_fwf(self.path, dtype = object, header = None)## Read data as Pandas DataFrame
        data_8 = data.loc[8,:].str[6:] ## Select data of column of wavelengths

        data_nm_dataframe =pd.read_csv(StringIO(data_8[0]))

        with open(self.path,'r',encoding='utf-8') as f:
            content = f.read()

        flag = 0
        for index in range(len(content)):##find the start point  of time and intensity data, pointer is the 'index'
            if (content[index] == '\n') and (flag != 9):
                flag = flag + 1
            elif (content[index] == '\n') and (flag == 9):
                break
            else:
                continue

        data_ns = pd.read_csv(StringIO(content[index:len(content)]), names = data_nm_dataframe.columns[0:len(set(data_nm_dataframe))]) ## Read data of time and gray 
        img_nm_ns = np.array(data_ns)    ## Transform to numpy array                                image as DataFrame; names is a 640x0 array indicates the wavelengths range
        
        self.data_frame = data_ns
        self.data_array = img_nm_ns
        
    def cal_846nm(self):
        time_total, wavelength_total = self.data_array.shape ## Generate an array contains intensity versus time data on 846nm
        data_846nm = np.zeros((time_total,), dtype = float )

        # for i in range(wavelength_total):
        #     data_846nm = self.data_array[:,i] + data_846nm
        data_846nm = np.sum(self.data_array,axis = 1)

        return data_846nm/wavelength_total
    
    def return_dataframe(self):
        
        return self.data_frame
    
    def return_array(self):
        return self.data_array

# %%
dict0 = {}
for i in range(1,100):
    dict0[i] = '.\\20230210\\常温\\Sample'+str(i)+'.txt'
dict0[0] = '.\\20230210\\常温\\irf00.txt'

dict1 = {}
for i in range(1,100):
    dict1[i] = '.\\20230211\\常温\\Sample'+str(i)+'.txt'
dict1[0] = '.\\20230211\\常温\\irf00.txt'

dict2 = {}
for i in range(1,100):
    dict2[i] = '.\\20230212\\常温\\Sample'+str(i)+'.txt'
dict2[0] = '.\\20230212\\常温\\irf00.txt'

dict3 = {}
for i in range(1,100):
    dict3[i] = '.\\20230213\\常温\\Sample'+str(i)+'.txt'
dict3[0] = '.\\20230213\\常温\\irf00.txt'

dict4 = {}
for i in range(1,100):
    dict4[i] = '.\\20230215\\常温\\Sample'+str(i)+'.txt'
dict4[0] = '.\\20230215\\常温\\irf00.txt'

dict5 = {}
for i in range(1,100):
    dict5[i] = '.\\20230217\\常温\\Sample'+str(i)+'.txt'
dict5[0] = '.\\20230217\\常温\\irf00.txt'

dict6 = {}
for i in range(1,100):
    dict6[i] = '.\\20230218\\常温\\Sample'+str(i)+'.txt'
dict6[0] = '.\\20230218\\常温\\irf00.txt'

dict7 = {}
for i in range(1,100):
    dict7[i] = '.\\20230219\\常温\\Sample'+str(i)+'.txt'
dict7[0] = '.\\20230219\\常温\\irf00.txt'

dict8 = {}
for i in range(1,100):
    dict8[i] = '.\\20230221\\常温\\Sample'+str(i)+'.txt'
dict8[0] = '.\\20230221\\常温\\irf00.txt'

dict9 = {}
for i in range(1,100):
    dict9[i] = '.\\20230223\\常温\\Sample'+str(i)+'.txt'
dict9[0] = '.\\20230223\\常温\\irf00.txt'

dict10 = {}
for i in range(1,100):
    dict10[i] = '.\\20230225\\常温\\Sample'+str(i)+'.txt'
dict10[0] = '.\\20230225\\常温\\irf00.txt'

dict11 = {}
for i in range(1,100):
    dict11[i] = '.\\20230227\\常温\\Sample'+str(i)+'.txt'
dict11[0] = '.\\20230227\\常温\\irf00.txt'

dictn = [dict0,dict1,dict2,dict3,dict4,dict5,dict6,dict7,dict8,dict9,dict10,dict11]

# %%
class analyze(object):
    def __init__(self):

        return

    
    def read_everyday(self,dict0,radius):    
        files = os.listdir(dict0[0][0:-10])   # 读入文件夹
        N = len(files)       # 统计文件夹中的文件个数
        scat = [None]*N
        data_480multi9 = np.zeros((N,480), dtype = float)
        time_index = np.zeros((N,480))
        radius0 = np.zeros((N-1,))
        j=0
        for i in range(0,100):
            if os.path.exists(dict0[i]):
                scat[j] = process_hyperspec(dict0[i], i)
                scat[j].read_data()
                data_480multi9[j,:] = scat[j].cal_846nm()
                time_index[j] = scat[j].return_dataframe().index
                if(i!=0):
                    radius0[j-1] = radius[i-1]
                j=j+1
            else:
                pass
        return data_480multi9,time_index,N,radius0

    def generate_h_y(self,data_480multi9,N):
        kernel0 = np.ones((10,))
        data_smooth = np.zeros((N-1,480))
        
        # for i in range(N-1):
        #     data_smooth[i] = np.convolve(kernel0,data_480multi9[i+1],'same')/np.sum(kernel0)

        def smooth(data):   #函数，用来平滑
            return np.convolve(kernel0,data,'same')/np.sum(kernel0)
        
        data_Y = data_480multi9[1:N]
        data_smooth = np.array([smooth(data_Y[i]) for i in range(data_Y.shape[0])])  #使用隐式循环来遍历

        y = np.zeros((data_smooth.shape[0],data_smooth.shape[1]*2-1))
        y[:,0:data_smooth.shape[1]] = data_smooth
        h = np.convolve(kernel0,data_480multi9[0],'same')/np.sum(kernel0)
        return h,y

# %%
class read_radius():
    def read_radius(self,AMOUNT_EXP):
        data1 = pd.read_excel('./kiwi_data.xlsx',sheet_name=1,header=None)
        data2 = np.nan_to_num(np.array(data1))
        r_before = data2[:,1]
        r_after = data2[:,2]
        sum1 = 0
        sum2 = 0
        count = 0
        for i in range(data2.shape[0]):
            if(r_before[i]!= 0 and r_after[i]!=0):
                sum1 = sum1+r_before[i]
                sum2 = sum2+r_after[i]
                count = count+1
        delta = (sum2-sum1)/count/AMOUNT_EXP
        radius = [None]*AMOUNT_EXP
        radius[0] = r_before
        for i in range(1,AMOUNT_EXP):
            radius[i] = radius[i-1] + delta
        return radius

# %%
ana = analyze()
H = []
Y = []
TIME = []
R = []
AMOUNT_EXP = len(dictn)
read_radius_0 = read_radius()
radius = read_radius_0.read_radius(AMOUNT_EXP)

def iterate_AMOUNT_EXP(i):  #定义获取每个 H,Y,TIME,R 的方法
    data_480multi9,time_index,N,radius0 = ana.read_everyday(dictn[i],radius[i])
    h,y = ana.generate_h_y(data_480multi9,N)

    return h,y,time_index,radius0
H_Y_TIME_R = list(iterate_AMOUNT_EXP(i) for i in range(AMOUNT_EXP))
# for i in range(AMOUNT_EXP):
#     radius = ana.read_radius()
#     data_480multi9,time_index,N,radius0 = ana.read_everyday(dictn[i],radius)
#     h,y = ana.generate_h_y(data_480multi9,N)
#     H.append(h)
#     Y.append(y)
#     TIME.append(time_index)
#     R.append(radius0)
H = [H_Y_TIME_R[i][0] for i in range(len(H_Y_TIME_R))]
Y = [H_Y_TIME_R[i][1] for i in range(len(H_Y_TIME_R))]
TIME = [H_Y_TIME_R[i][2] for i in range(len(H_Y_TIME_R))]
R = [H_Y_TIME_R[i][3] for i in range(len(H_Y_TIME_R))]

# %%
##########################################
fig = plt.figure(figsize = (8,8))
fig.suptitle('raw data of all normal temperature sample')
days = np.array([0,1,2,3,5,7,8,9,11,13,15,17])
for i in range(AMOUNT_EXP):
    plt.subplot(3,4,i+1)
    plt.title('day'+str(days[i]))
    for j in range(Y[i].shape[0]):
        plt.plot(TIME[0][i]*1e-9,Y[i][j,0:480])
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)

plt.show()

# %%
##########################################
fig = plt.figure(figsize = (4,4))
for i in range(AMOUNT_EXP):
    plt.plot(TIME[0][50]*1e-9,H[i])
    # plt.title.set_text(dict0[i][9:-4])
    fig.tight_layout(pad=1.1)


plt.show()

# %%
class calculate_miu_s1(object):
    
    def __init__(self, h, y, time_index,d):
        self.h = h
        self.y = y
        self.time = time_index
        self.d = d
        return None
    
    def transmittance(self, d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
    
    def error_cal(self, x):
        miu_a = x[0]
        # miu_a = 6.0
        miu_s = x[1]
         
        # k = 0.1
        # miu_a = 0.01e2
        g = 0.85
        # d = 0.38e-3
        d = self.d
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = self.time*1e-9
        # miu_s = miu_s*1e4
        intensity1 = np.zeros((T, ), dtype = float)
        # for i in range(time.shape[0] ):

        #     intensity1[i] = calculate_miu_s1.transmittance(self, d, time[i], c, g, miu_a, miu_s)
        intensity1 = np.array([calculate_miu_s1.transmittance(self, d, time[i], c, g, miu_a, miu_s) 
                               for i in range(time.shape[0])])  # 隐式循环

        y2 = np.convolve(intensity1, self.h)
        self.intensity = intensity1
        self.y_convolved = y2
        y2 = y2/max(abs(y2))
        y3 = self.y/max(abs(self.y))
        
        return np.sum(abs(y2 - y3))
#         return time

    
    def get_convolved_signal(self):
        return self.y_convolved
        
    def get_x(self):
        return self.intensity

# %%
class call_cal(object):
    def __init__(self):
        return
    def call_cal(self,h,y,time_index,radius):
            # %%capture --no-display
            miu_s_get = np.zeros((y.shape[0],2))
            m1=[None]*y.shape[0]
            fun_value = np.zeros((y.shape[0],))
            bnds = ((6.0,8.7), (0, None))
            convolved = np.zeros((y.shape[0],959))
            for i in range(y.shape[0]):
                d = radius[i]*1e-3
                m1[i] = calculate_miu_s1(h, y[i], time_index[i+1],d)
                try:
                    minu = minimize(m1[i].error_cal, x0 = [0.065e2,100e2], method  = 
                                    'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
                    miu_s_get[i], fun_value[i] = minu.x, minu.fun # Nelder-Mead
                    convolved[i] = m1[i].get_convolved_signal()
                except:
                    print("one error occured, on the "+str(i)+"th kiwi")
            # def iter(i):
            #     d = radius[i]*1e-3
            #     m1[i] = calculate_miu_s1(h, y[i], time_index[i+1],d)
            #     try:
            #         minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = 
            # bnds, options={"xtol" : 1e-20, "disp":True})
            #         miu_s_get_, fun_value_ = minu.x, minu.fun # Nelder-Mead
            #     except:
            #         print("one error occured, on the "+str(i)+"th kiwi")
            #     return miu_s_get_,fun_value_
            # miu_s_get = np.array([iter(i)[0] for i in range(y.shape[0])])

            return miu_s_get,convolved

    def call_(self,H,Y,TIME,R,AMOUNT_EXP):
        miu_as = []
        convolved_sig = []
        for i in range(AMOUNT_EXP):
            miu_s_get,convolved = self.call_cal(H[i],Y[i],TIME[i],R[i])
            miu_as.append(miu_s_get)
            convolved_sig.append(convolved)
        return miu_as,convolved_sig

# %%
call = call_cal()
miu_as,convolved = call.call_(H,Y,TIME,R,AMOUNT_EXP)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13688/2868100735.py:15: OptimizeWarning: Unknown solver options: xtol
#   minu = minimize(m1[i].error_cal, x0 = [0.065e2,100e2], method  =
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13688/3303426279.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   Z0 = 1/(miu_s_prime)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13688/3303426279.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13688/3303426279.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13688/3303426279.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_13688/3303426279.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
# Optimization terminated successfully.
#          Current function value: 23.767277
#          Iterations: 85
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 17.393991
#          Iterations: 75
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 13.617937
#          Iterations: 48
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 17.155697
#          Iterations: 67
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 28.636213
#          Iterations: 63
#          Function evaluations: 115
# Optimization terminated successfully.
#          Current function value: 18.042274
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 23.544451
#          Iterations: 70
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 17.499184
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 23.406164
#          Iterations: 80
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 24.942776
#          Iterations: 73
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 13.844663
#          Iterations: 54
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 11.617126
#          Iterations: 42
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 27.545665
#          Iterations: 81
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 25.905071
#          Iterations: 84
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 24.078722
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 17.882963
#          Iterations: 71
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 14.890984
#          Iterations: 85
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 19.892234
#          Iterations: 102
#          Function evaluations: 191
# Optimization terminated successfully.
#          Current function value: 25.385180
#          Iterations: 50
#          Function evaluations: 97
# Optimization terminated successfully.
#          Current function value: 17.760193
#          Iterations: 64
#          Function evaluations: 120
# Optimization terminated successfully.
#          Current function value: 21.222834
#          Iterations: 87
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 13.359210
#          Iterations: 49
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 14.200134
#          Iterations: 54
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 17.880227
#          Iterations: 93
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 54.393476
#          Iterations: 91
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 16.917385
#          Iterations: 83
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 28.777266
#          Iterations: 94
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 21.321574
#          Iterations: 83
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 11.600173
#          Iterations: 53
#          Function evaluations: 104
# Optimization terminated successfully.
#          Current function value: 39.268203
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 11.827200
#          Iterations: 51
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 25.105860
#          Iterations: 53
#          Function evaluations: 104
# Optimization terminated successfully.
#          Current function value: 17.548401
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 15.871627
#          Iterations: 70
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 23.171554
#          Iterations: 100
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 17.042883
#          Iterations: 135
#          Function evaluations: 258
# Optimization terminated successfully.
#          Current function value: 12.573324
#          Iterations: 49
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 30.227795
#          Iterations: 82
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 21.942359
#          Iterations: 95
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 11.077412
#          Iterations: 43
#          Function evaluations: 77
# Optimization terminated successfully.
#          Current function value: 13.440738
#          Iterations: 47
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 17.221977
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 21.320908
#          Iterations: 88
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 36.461250
#          Iterations: 90
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 21.187195
#          Iterations: 99
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 15.460132
#          Iterations: 46
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 35.771877
#          Iterations: 91
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 37.710928
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 43.584095
#          Iterations: 74
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 17.105197
#          Iterations: 113
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 24.629829
#          Iterations: 102
#          Function evaluations: 191
# Optimization terminated successfully.
#          Current function value: 32.383146
#          Iterations: 49
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 17.017386
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 26.139878
#          Iterations: 105
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 15.618611
#          Iterations: 91
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 15.146164
#          Iterations: 53
#          Function evaluations: 101
# Optimization terminated successfully.
#          Current function value: 29.284166
#          Iterations: 117
#          Function evaluations: 220
# Optimization terminated successfully.
#          Current function value: 14.604255
#          Iterations: 42
#          Function evaluations: 76
# Optimization terminated successfully.
#          Current function value: 14.184090
#          Iterations: 47
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 26.150982
#          Iterations: 51
#          Function evaluations: 100
# Optimization terminated successfully.
#          Current function value: 19.377191
#          Iterations: 46
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 15.263572
#          Iterations: 44
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 25.191494
#          Iterations: 49
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 22.065186
#          Iterations: 87
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 19.028784
#          Iterations: 95
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 15.406867
#          Iterations: 56
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 15.905858
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 25.812707
#          Iterations: 45
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 20.436258
#          Iterations: 93
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 22.613552
#          Iterations: 90
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 13.133844
#          Iterations: 94
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 33.405515
#          Iterations: 145
#          Function evaluations: 272
# Optimization terminated successfully.
#          Current function value: 11.942828
#          Iterations: 47
#          Function evaluations: 83
# Optimization terminated successfully.
#          Current function value: 18.508989
#          Iterations: 82
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 25.354990
#          Iterations: 78
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 20.128571
#          Iterations: 47
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 27.545574
#          Iterations: 80
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 17.393842
#          Iterations: 50
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 18.839218
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 38.700698
#          Iterations: 64
#          Function evaluations: 121
# Optimization terminated successfully.
#          Current function value: 26.210985
#          Iterations: 49
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 15.766375
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 15.491260
#          Iterations: 46
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 16.304122
#          Iterations: 107
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 35.900673
#          Iterations: 82
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 22.036725
#          Iterations: 50
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 30.617644
#          Iterations: 96
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 30.884991
#          Iterations: 64
#          Function evaluations: 118
# Optimization terminated successfully.
#          Current function value: 32.990137
#          Iterations: 50
#          Function evaluations: 96
# Optimization terminated successfully.
#          Current function value: 17.403301
#          Iterations: 83
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 21.452496
#          Iterations: 52
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 19.574178
#          Iterations: 132
#          Function evaluations: 253
# Optimization terminated successfully.
#          Current function value: 14.339627
#          Iterations: 48
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 14.494441
#          Iterations: 81
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 19.213322
#          Iterations: 47
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 30.420814
#          Iterations: 106
#          Function evaluations: 205
# Optimization terminated successfully.
#          Current function value: 34.167130
#          Iterations: 53
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 17.882439
#          Iterations: 48
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 45.102744
#          Iterations: 99
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: 13.049243
#          Iterations: 52
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 26.688139
#          Iterations: 84
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 32.862550
#          Iterations: 53
#          Function evaluations: 99
# Optimization terminated successfully.
#          Current function value: 21.417681
#          Iterations: 63
#          Function evaluations: 119
# Optimization terminated successfully.
#          Current function value: 13.357222
#          Iterations: 115
#          Function evaluations: 220
# Optimization terminated successfully.
#          Current function value: 12.387122
#          Iterations: 69
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 21.260850
#          Iterations: 58
#          Function evaluations: 113
# Optimization terminated successfully.
#          Current function value: 23.318963
#          Iterations: 54
#          Function evaluations: 101
# Optimization terminated successfully.
#          Current function value: 20.820579
#          Iterations: 78
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 13.414209
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 18.238411
#          Iterations: 52
#          Function evaluations: 99
# Optimization terminated successfully.
#          Current function value: 15.368650
#          Iterations: 108
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: 28.962857
#          Iterations: 49
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 15.482466
#          Iterations: 47
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 28.658364
#          Iterations: 64
#          Function evaluations: 119
# Optimization terminated successfully.
#          Current function value: 20.446584
#          Iterations: 59
#          Function evaluations: 106
# Optimization terminated successfully.
#          Current function value: 13.039139
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 27.281978
#          Iterations: 57
#          Function evaluations: 113
# Optimization terminated successfully.
#          Current function value: 16.627952
#          Iterations: 48
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 20.657935
#          Iterations: 44
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 15.983387
#          Iterations: 52
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 17.634010
#          Iterations: 109
#          Function evaluations: 209
# Optimization terminated successfully.
#          Current function value: 16.290347
#          Iterations: 45
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 16.631423
#          Iterations: 112
#          Function evaluations: 215
# Optimization terminated successfully.
#          Current function value: 14.748457
#          Iterations: 59
#          Function evaluations: 116
# Optimization terminated successfully.
#          Current function value: 24.885729
#          Iterations: 78
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 17.925252
#          Iterations: 51
#          Function evaluations: 96
# Optimization terminated successfully.
#          Current function value: 16.029226
#          Iterations: 47
#          Function evaluations: 81
# Optimization terminated successfully.
#          Current function value: 13.058848
#          Iterations: 46
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 17.251762
#          Iterations: 53
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 16.381780
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 38.316701
#          Iterations: 50
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 16.467974
#          Iterations: 53
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 17.442446
#          Iterations: 45
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 25.211689
#          Iterations: 51
#          Function evaluations: 96
# Optimization terminated successfully.
#          Current function value: 31.556597
#          Iterations: 67
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 33.224517
#          Iterations: 50
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 20.313325
#          Iterations: 65
#          Function evaluations: 122
# Optimization terminated successfully.
#          Current function value: 21.516973
#          Iterations: 98
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 27.257023
#          Iterations: 47
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 11.672048
#          Iterations: 44
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 20.150762
#          Iterations: 86
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 14.416235
#          Iterations: 89
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 13.606279
#          Iterations: 47
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 23.911426
#          Iterations: 100
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 15.865689
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 14.074768
#          Iterations: 47
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 27.974618
#          Iterations: 46
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 24.457930
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 17.962543
#          Iterations: 48
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 21.284712
#          Iterations: 54
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 13.836503
#          Iterations: 118
#          Function evaluations: 226
# Optimization terminated successfully.
#          Current function value: 14.005614
#          Iterations: 51
#          Function evaluations: 97
# Optimization terminated successfully.
#          Current function value: 19.185152
#          Iterations: 46
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 18.945258
#          Iterations: 98
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 24.970816
#          Iterations: 48
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 23.876272
#          Iterations: 99
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 22.224453
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 18.870821
#          Iterations: 50
#          Function evaluations: 96
# Optimization terminated successfully.
#          Current function value: 13.796542
#          Iterations: 52
#          Function evaluations: 98
# Optimization terminated successfully.
#          Current function value: 15.230700
#          Iterations: 51
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 17.949195
#          Iterations: 98
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 20.663122
#          Iterations: 48
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 23.584523
#          Iterations: 47
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 26.687941
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 23.693106
#          Iterations: 47
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 15.640031
#          Iterations: 104
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 22.855684
#          Iterations: 58
#          Function evaluations: 109
# Optimization terminated successfully.
#          Current function value: 20.684493
#          Iterations: 52
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 17.107762
#          Iterations: 56
#          Function evaluations: 108
# Optimization terminated successfully.
#          Current function value: 17.798148
#          Iterations: 49
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 12.787986
#          Iterations: 51
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 30.907832
#          Iterations: 64
#          Function evaluations: 123
# Optimization terminated successfully.
#          Current function value: 22.290478
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 26.973456
#          Iterations: 90
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 24.014608
#          Iterations: 81
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 32.599987
#          Iterations: 69
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 20.075876
#          Iterations: 95
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 14.178174
#          Iterations: 48
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 24.519535
#          Iterations: 75
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 11.359737
#          Iterations: 47
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 17.477759
#          Iterations: 45
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 16.249585
#          Iterations: 50
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 29.148477
#          Iterations: 91
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 31.285864
#          Iterations: 57
#          Function evaluations: 107
# Optimization terminated successfully.
#          Current function value: 16.415671
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 38.914834
#          Iterations: 91
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 30.817554
#          Iterations: 100
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 12.936871
#          Iterations: 79
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 19.701944
#          Iterations: 49
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 17.518211
#          Iterations: 103
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: 28.682676
#          Iterations: 78
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 14.664830
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 14.726484
#          Iterations: 47
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 15.307515
#          Iterations: 47
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 17.624397
#          Iterations: 58
#          Function evaluations: 108
# Optimization terminated successfully.
#          Current function value: 41.311382
#          Iterations: 59
#          Function evaluations: 114
# Optimization terminated successfully.
#          Current function value: 15.149826
#          Iterations: 119
#          Function evaluations: 225
# Optimization terminated successfully.
#          Current function value: 33.175371
#          Iterations: 82
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 21.690785
#          Iterations: 77
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 12.023958
#          Iterations: 94
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 39.442586
#          Iterations: 113
#          Function evaluations: 216
# Optimization terminated successfully.
#          Current function value: 12.258665
#          Iterations: 44
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 23.378849
#          Iterations: 64
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 12.661312
#          Iterations: 44
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 12.140701
#          Iterations: 71
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 19.058438
#          Iterations: 45
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 18.914045
#          Iterations: 111
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 15.100772
#          Iterations: 86
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 33.561423
#          Iterations: 91
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 25.836854
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 12.288135
#          Iterations: 42
#          Function evaluations: 76
# Optimization terminated successfully.
#          Current function value: 12.987457
#          Iterations: 45
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 21.988675
#          Iterations: 54
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 15.936570
#          Iterations: 93
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 37.859882
#          Iterations: 103
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 17.830406
#          Iterations: 92
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 13.603547
#          Iterations: 97
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 29.907167
#          Iterations: 81
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 32.013363
#          Iterations: 51
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 47.438808
#          Iterations: 52
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 16.318992
#          Iterations: 158
#          Function evaluations: 306
# Optimization terminated successfully.
#          Current function value: 34.825001
#          Iterations: 60
#          Function evaluations: 108
# Optimization terminated successfully.
#          Current function value: 34.157089
#          Iterations: 97
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 12.566445
#          Iterations: 49
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 22.440064
#          Iterations: 52
#          Function evaluations: 98
# Optimization terminated successfully.
#          Current function value: 12.815325
#          Iterations: 99
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 15.518371
#          Iterations: 54
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 22.165453
#          Iterations: 62
#          Function evaluations: 119
# Optimization terminated successfully.
#          Current function value: 14.915343
#          Iterations: 53
#          Function evaluations: 106
# Optimization terminated successfully.
#          Current function value: 12.089530
#          Iterations: 82
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 22.799602
#          Iterations: 87
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 19.251164
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 13.556392
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 23.910511
#          Iterations: 55
#          Function evaluations: 108
# Optimization terminated successfully.
#          Current function value: 14.750583
#          Iterations: 110
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: 20.778406
#          Iterations: 93
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 13.999688
#          Iterations: 49
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 14.434604
#          Iterations: 89
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 29.546148
#          Iterations: 43
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 20.396373
#          Iterations: 115
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 18.194718
#          Iterations: 71
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 15.565085
#          Iterations: 74
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 17.153729
#          Iterations: 100
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 12.941776
#          Iterations: 51
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 22.390151
#          Iterations: 74
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 19.127851
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 17.121302
#          Iterations: 45
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 31.381214
#          Iterations: 87
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 18.135889
#          Iterations: 86
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 17.772212
#          Iterations: 92
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 21.626723
#          Iterations: 66
#          Function evaluations: 122
# Optimization terminated successfully.
#          Current function value: 19.454174
#          Iterations: 101
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 16.590947
#          Iterations: 94
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 19.286884
#          Iterations: 48
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 20.028905
#          Iterations: 57
#          Function evaluations: 111
# Optimization terminated successfully.
#          Current function value: 28.654584
#          Iterations: 94
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 21.256125
#          Iterations: 88
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 27.428054
#          Iterations: 71
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 24.325268
#          Iterations: 66
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 27.550728
#          Iterations: 69
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 14.544040
#          Iterations: 75
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 15.078738
#          Iterations: 56
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 31.573758
#          Iterations: 52
#          Function evaluations: 98
# Optimization terminated successfully.
#          Current function value: 19.838249
#          Iterations: 50
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 15.857847
#          Iterations: 88
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 17.899017
#          Iterations: 54
#          Function evaluations: 106
# Optimization terminated successfully.
#          Current function value: 40.905376
#          Iterations: 83
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 38.419176
#          Iterations: 100
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 21.669667
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 38.529772
#          Iterations: 53
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 22.252192
#          Iterations: 48
#          Function evaluations: 83
# Optimization terminated successfully.
#          Current function value: 24.937207
#          Iterations: 86
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 15.736116
#          Iterations: 68
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 16.551434
#          Iterations: 43
#          Function evaluations: 77
# Optimization terminated successfully.
#          Current function value: 16.276934
#          Iterations: 49
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 16.063125
#          Iterations: 58
#          Function evaluations: 111
# Optimization terminated successfully.
#          Current function value: 30.874115
#          Iterations: 96
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 21.634212
#          Iterations: 51
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 26.163032
#          Iterations: 53
#          Function evaluations: 100
# Optimization terminated successfully.
#          Current function value: 18.802959
#          Iterations: 94
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 13.835882
#          Iterations: 53
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 23.755859
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 17.173858
#          Iterations: 45
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 23.496626
#          Iterations: 47
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 20.708602
#          Iterations: 46
#          Function evaluations: 81
# Optimization terminated successfully.
#          Current function value: 14.865947
#          Iterations: 81
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 17.169997
#          Iterations: 44
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 14.223977
#          Iterations: 95
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 18.513773
#          Iterations: 45
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 35.544975
#          Iterations: 73
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 19.937520
#          Iterations: 47
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 15.177941
#          Iterations: 46
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 16.287473
#          Iterations: 48
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 21.771934
#          Iterations: 89
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 22.457397
#          Iterations: 47
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 44.510999
#          Iterations: 73
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 23.860229
#          Iterations: 78
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 15.505429
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 27.378780
#          Iterations: 46
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 31.477436
#          Iterations: 60
#          Function evaluations: 111
# Optimization terminated successfully.
#          Current function value: 44.402212
#          Iterations: 58
#          Function evaluations: 108
# Optimization terminated successfully.
#          Current function value: 16.901844
#          Iterations: 75
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 29.205877
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 29.965838
#          Iterations: 49
#          Function evaluations: 88
# Optimization terminated successfully.
#          Current function value: 18.211417
#          Iterations: 47
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 29.444639
#          Iterations: 65
#          Function evaluations: 124
# Optimization terminated successfully.
#          Current function value: 13.622006
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 24.103123
#          Iterations: 52
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 26.459465
#          Iterations: 47
#          Function evaluations: 81
# Optimization terminated successfully.
#          Current function value: 18.272403
#          Iterations: 47
#          Function evaluations: 81
# Optimization terminated successfully.
#          Current function value: 15.640971
#          Iterations: 50
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 23.703714
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 37.118674
#          Iterations: 56
#          Function evaluations: 97
# Optimization terminated successfully.
#          Current function value: 16.932743
#          Iterations: 46
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 22.997221
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 17.671788
#          Iterations: 48
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 13.786009
#          Iterations: 52
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 16.242290
#          Iterations: 45
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 17.203808
#          Iterations: 51
#          Function evaluations: 97
# Optimization terminated successfully.
#          Current function value: 18.944564
#          Iterations: 49
#          Function evaluations: 83
# Optimization terminated successfully.
#          Current function value: 18.779288
#          Iterations: 75
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 16.229442
#          Iterations: 81
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 20.220395
#          Iterations: 57
#          Function evaluations: 108
# Optimization terminated successfully.
#          Current function value: 19.543137
#          Iterations: 49
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 15.867052
#          Iterations: 49
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 17.214180
#          Iterations: 106
#          Function evaluations: 191
# Optimization terminated successfully.
#          Current function value: 22.430643
#          Iterations: 49
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 21.999619
#          Iterations: 46
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 27.016831
#          Iterations: 46
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 23.263739
#          Iterations: 49
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 32.472808
#          Iterations: 147
#          Function evaluations: 284
# Optimization terminated successfully.
#          Current function value: 22.987155
#          Iterations: 49
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 23.015941
#          Iterations: 47
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 19.496694
#          Iterations: 46
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 19.679412
#          Iterations: 51
#          Function evaluations: 98
# Optimization terminated successfully.
#          Current function value: 26.348943
#          Iterations: 53
# ...
#          Current function value: 18.380808
#          Iterations: 50
#          Function evaluations: 96
# Optimization terminated successfully.
#          Current function value: 13.582348
#          Iterations: 43
#          Function evaluations: 77
# Optimization terminated successfully.
#          Current function value: 16.158400
#          Iterations: 46
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 37.677627
#          Iterations: 46
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 38.095952
#          Iterations: 74
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 12.250521
#          Iterations: 92
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 19.626246
#          Iterations: 85
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 21.098733
#          Iterations: 48
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 9.416692
#          Iterations: 53
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 19.621214
#          Iterations: 116
#          Function evaluations: 225
# Optimization terminated successfully.
#          Current function value: 12.271962
#          Iterations: 100
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 13.196705
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 21.553269
#          Iterations: 51
#          Function evaluations: 98
# Optimization terminated successfully.
#          Current function value: 10.067596
#          Iterations: 48
#          Function evaluations: 83
# Optimization terminated successfully.
#          Current function value: 10.885485
#          Iterations: 49
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 22.830629
#          Iterations: 50
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 24.128695
#          Iterations: 51
#          Function evaluations: 100
# Optimization terminated successfully.
#          Current function value: 17.120320
#          Iterations: 47
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 18.959087
#          Iterations: 95
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 12.347538
#          Iterations: 100
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 8.066817
#          Iterations: 60
#          Function evaluations: 119
# Optimization terminated successfully.
#          Current function value: 12.386331
#          Iterations: 47
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 15.131197
#          Iterations: 94
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 15.972198
#          Iterations: 45
#          Function evaluations: 81
# Optimization terminated successfully.
#          Current function value: 16.528420
#          Iterations: 97
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 20.057660
#          Iterations: 75
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 13.100261
#          Iterations: 77
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 15.289782
#          Iterations: 118
#          Function evaluations: 222
# Optimization terminated successfully.
#          Current function value: 10.496611
#          Iterations: 47
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 19.520347
#          Iterations: 93
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 17.521930
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 11.318099
#          Iterations: 45
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 20.596466
#          Iterations: 50
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 11.973823
#          Iterations: 48
#          Function evaluations: 82
# Optimization terminated successfully.
#          Current function value: 11.600954
#          Iterations: 49
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 13.945289
#          Iterations: 91
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 14.950166
#          Iterations: 45
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 16.729576
#          Iterations: 112
#          Function evaluations: 215
# Optimization terminated successfully.
#          Current function value: 15.960382
#          Iterations: 47
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 12.751914
#          Iterations: 53
#          Function evaluations: 99
# Optimization terminated successfully.
#          Current function value: 35.199346
#          Iterations: 66
#          Function evaluations: 119
# Optimization terminated successfully.
#          Current function value: 18.696236
#          Iterations: 52
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 16.546490
#          Iterations: 53
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 16.418504
#          Iterations: 50
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 21.707654
#          Iterations: 54
#          Function evaluations: 102
# Optimization terminated successfully.
#          Current function value: 13.917773
#          Iterations: 48
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 13.219653
#          Iterations: 44
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 23.107929
#          Iterations: 110
#          Function evaluations: 200
# Optimization terminated successfully.
#          Current function value: 9.100030
#          Iterations: 52
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 14.351717
#          Iterations: 78
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 14.787299
#          Iterations: 53
#          Function evaluations: 100
# Optimization terminated successfully.
#          Current function value: 14.781751
#          Iterations: 95
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 36.638609
#          Iterations: 79
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 16.723307
#          Iterations: 50
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 24.809735
#          Iterations: 87
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 14.959938
#          Iterations: 48
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 9.410726
#          Iterations: 48
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 18.189652
#          Iterations: 84
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 10.140038
#          Iterations: 61
#          Function evaluations: 116
# Optimization terminated successfully.
#          Current function value: 30.132095
#          Iterations: 50
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 14.218120
#          Iterations: 96
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 16.114488
#          Iterations: 50
#          Function evaluations: 94
# Optimization terminated successfully.
#          Current function value: 17.182400
#          Iterations: 43
#          Function evaluations: 78
# Optimization terminated successfully.
#          Current function value: 24.726446
#          Iterations: 57
#          Function evaluations: 100
# Optimization terminated successfully.
#          Current function value: 41.926520
#          Iterations: 77
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 13.204422
#          Iterations: 89
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 18.202891
#          Iterations: 162
#          Function evaluations: 315
# Optimization terminated successfully.
#          Current function value: 22.465800
#          Iterations: 44
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 11.175758
#          Iterations: 48
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 28.274465
#          Iterations: 62
#          Function evaluations: 114
# Optimization terminated successfully.
#          Current function value: 13.090040
#          Iterations: 47
#          Function evaluations: 87
# Optimization terminated successfully.
#          Current function value: 16.312571
#          Iterations: 40
#          Function evaluations: 74
# Optimization terminated successfully.
#          Current function value: 21.212624
#          Iterations: 92
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 11.136539
#          Iterations: 54
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 10.281089
#          Iterations: 54
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 19.230252
#          Iterations: 48
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 19.499807
#          Iterations: 56
#          Function evaluations: 104
# Optimization terminated successfully.
#          Current function value: 16.087826
#          Iterations: 53
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 21.158530
#          Iterations: 76
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 13.116497
#          Iterations: 100
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 10.382689
#          Iterations: 45
#          Function evaluations: 90
# Optimization terminated successfully.
#          Current function value: 10.265022
#          Iterations: 54
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 14.749218
#          Iterations: 45
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 16.093654
#          Iterations: 57
#          Function evaluations: 98
# Optimization terminated successfully.
#          Current function value: 19.941133
#          Iterations: 65
#          Function evaluations: 120
# Optimization terminated successfully.
#          Current function value: 20.322557
#          Iterations: 94
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 13.935130
#          Iterations: 69
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 16.111090
#          Iterations: 82
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 11.011093
#          Iterations: 45
#          Function evaluations: 85
# Optimization terminated successfully.
#          Current function value: 14.617760
#          Iterations: 98
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 19.357122
#          Iterations: 46
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 11.576338
#          Iterations: 49
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 20.863978
#          Iterations: 48
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 11.256597
#          Iterations: 54
#          Function evaluations: 93
# Optimization terminated successfully.
#          Current function value: 10.653655
#          Iterations: 51
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 14.193774
#          Iterations: 49
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 10.564013
#          Iterations: 53
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 24.132423
#          Iterations: 44
#          Function evaluations: 84
# Optimization terminated successfully.
#          Current function value: 16.990039
#          Iterations: 51
#          Function evaluations: 100
# Optimization terminated successfully.
#          Current function value: 14.433006
#          Iterations: 52
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 23.149201
#          Iterations: 53
#          Function evaluations: 103
# Optimization terminated successfully.
#          Current function value: 22.526426
#          Iterations: 48
#          Function evaluations: 92
# Optimization terminated successfully.
#          Current function value: 15.986170
#          Iterations: 45
#          Function evaluations: 80
# Optimization terminated successfully.
#          Current function value: 16.761840
#          Iterations: 51
#          Function evaluations: 89
# Optimization terminated successfully.
#          Current function value: 30.776512
#          Iterations: 43
#          Function evaluations: 77
# Optimization terminated successfully.
#          Current function value: 12.179715
#          Iterations: 53
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 12.236178
#          Iterations: 44
#          Function evaluations: 79
# Optimization terminated successfully.
#          Current function value: 18.389695
#          Iterations: 53
#          Function evaluations: 91
# Optimization terminated successfully.
#          Current function value: 10.723815
#          Iterations: 49
#          Function evaluations: 83
# Optimization terminated successfully.
#          Current function value: 14.865245
#          Iterations: 45
#          Function evaluations: 86
# Optimization terminated successfully.
#          Current function value: 14.536891
#          Iterations: 46
#          Function evaluations: 81
# Optimization terminated successfully.
#          Current function value: 26.668057
#          Iterations: 98
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 25.441418
#          Iterations: 64
#          Function evaluations: 120
# Optimization terminated successfully.
#          Current function value: 15.354069
#          Iterations: 51
#          Function evaluations: 99
# Optimization terminated successfully.
#          Current function value: 22.514724
#          Iterations: 45
#          Function evaluations: 79

# %%
mua = []
mus = []
for i in range(len(miu_as)):
    mua0 = []
    mus0 = []
    for j in range(len(miu_as[i])):
        mua0.append(miu_as[i][j][0])
        mus0.append(miu_as[i][j][1])
    mua.append(mua0)
    mus.append(mus0)

#  miu_as[i][j][0] -> mua  miu_as[i][j][1] -> mus

# %%
plt.figure(figsize = (10,10))
for i in range(0,6):
    plt.subplot(3,4,i+1)
    plt.hist(x = mus[i],bins = 20)
plt.show()

# %%
# def mean(x):
#     sum= np.sum(x)
#     i=0
#     for i in range(x.shape[0]):
#         if(x[i]!=0): i=i+1
#     return sum/i

# avg_miu = [None]*AMOUNT_EXP
# for i in range(AMOUNT_EXP):
#     avg_miu[i] = np.sum(miu_as[i],axis=0)/Y[i].shape[0]
avg_miu = [None]*AMOUNT_EXP
for i in range(AMOUNT_EXP):
    avg_0 = np.mean(miu_as[i][:,0])
    avg_1 = np.mean(miu_as[i][:,1])
    avg_i = np.array([avg_0,avg_1])
    avg_miu[i] = avg_i

    
mid_miu = [None]*AMOUNT_EXP
for i in range(AMOUNT_EXP):
    avg_0 = np.median(miu_as[i][:,0])
    avg_1 = np.median(miu_as[i][:,1])
    avg_i = np.array([avg_0,avg_1])
    mid_miu[i] = avg_i

# %%
avg_miu
# Out:
# [array([   7.72068881, 2799.78154453]),
#  array([   8.26408758, 2757.03512634]),
#  array([   7.68480723, 2791.89723371]),
#  array([   7.99146858, 2557.36523542]),
#  array([   7.3370115 , 2715.82409319]),
#  array([   7.92600399, 2741.20029456]),
#  array([   7.37216413, 2762.41556352]),
#  array([   7.77439956, 2705.30382861]),
#  array([   7.70464484, 2728.16509901]),
#  array([   7.73895026, 2709.03769454]),
#  array([   8.00742355, 2668.13394293]),
#  array([   8.25851014, 2587.79350028])]

# %%
mid_miu
# Out:
# [array([   8.00940765, 2755.00526516]),
#  array([   8.7       , 2733.15408059]),
#  array([   8.20600531, 2738.16491313]),
#  array([   8.7       , 2559.38833952]),
#  array([   7.10848248, 2659.21277186]),
#  array([   8.7       , 2657.64649028]),
#  array([   7.55803656, 2683.35081181]),
#  array([   8.7      , 2658.0598455]),
#  array([   8.20961766, 2702.07274845]),
#  array([   8.30038591, 2673.96015794]),
#  array([   8.7       , 2621.16491795]),
#  array([   8.7       , 2588.69597033])]

# %%
mua = []
for i in range(len(avg_miu)):
    mua.append(avg_miu[i][0])
mus = []
for i in range(len(avg_miu)):
    mus.append(avg_miu[i][1])
fig = plt.figure(figsize = (8,4))
fig.suptitle('mua&mus for kiwi in normal temperature')
ax0=plt.subplot(1,2,1)
ax0.set_title('mua')
ax0.set_xticks([0,1,2,3,5,7,8,9,11,13,15,17])
ax0.plot([0,1,2,3,5,7,8,9,11,13,15,17],mua)
ax1=plt.subplot(1,2,2)
ax1.set_title('mus')
ax1.set_xticks([0,1,2,3,5,7,8,9,11,13,15,17])
ax1.plot([0,1,2,3,5,7,8,9,11,13,15,17],mus)
plt.show()

# %%
#去掉第三天
mua = []
for i in range(len(avg_miu)):
    mua.append(avg_miu[i][0])
mus = []
for i in range(len(avg_miu)):
    mus.append(avg_miu[i][1])
fig = plt.figure(figsize = (8,4))
fig.suptitle('mua&mus for kiwi in normal temperature')
ax0=plt.subplot(1,2,1)
ax0.set_title('mua')
ax0.set_xticks([0,1,2,5,7,8,9,11,13,15,17])
index0 = np.array([0,1,2,4,5,6,7,8,9,10,11])
mua_1 = np.array(mua)
mus_1 = np.array(mus)
ax0.plot([0,1,2,5,7,8,9,11,13,15,17],mua_1[index0])
ax1=plt.subplot(1,2,2)
ax1.set_title('mus')
ax1.set_xticks([0,1,2,5,7,8,9,11,13,15,17])
ax1.plot([0,1,2,5,7,8,9,11,13,15,17],mus_1[index0])
plt.show()

# %%
mua = []
for i in range(len(mid_miu)):
    mua.append(mid_miu[i][0])
mus = []
for i in range(len(mid_miu)):
    mus.append(mid_miu[i][1])
plt.figure(figsize = (8,4))
ax0=plt.subplot(1,2,1)
ax0.set_title('mua')
ax0.set_xticks([0,1,2,3,5,7,8,9,11,13,15,17])
ax0.plot([0,1,2,3,5,7,8,9,11,13,15,17],mua)
ax1=plt.subplot(1,2,2)
ax1.set_title('mus')
ax1.set_xticks([0,1,2,3,5,7,8,9,11,13,15,17])
ax1.plot([0,1,2,3,5,7,8,9,11,13,15,17],mus)
plt.show()

# %%
AMOUNT_i = 3
AMOUNT_j = 3
i_rand = random.sample(range(0,len(Y)), AMOUNT_i)
j_rand = random.sample(range(0,len(Y[0])), AMOUNT_j)
plt.figure(figsize = (6,6))
for i in range(AMOUNT_i):
    for j in range(AMOUNT_j):
        plt.subplot(3,3,i*AMOUNT_j+j+1)
        plt.plot(convolved[i_rand[i]][j_rand[j]]/1.4e11)
        plt.plot(Y[i_rand[i]][j_rand[j]])
    
plt.tight_layout(pad=1.0)
plt.show()
