# %%
# calculate kiwifruit 's each parts' mua, mus, with equal scale enlarge
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# import tensorflow as tf
import math
# from scipy.optimize import fsolve
# from scipy.optimize import root
import scipy as scipy
from scipy.optimize import minimize
# from scipy import signal
# from scipy import linalg
# import scipy as scp
# import sympy as  syp
# from tensorflow.keras import backend as K
# from tensorflow.keras.layers import Layer
# from tensorflow.keras.models import Sequential
import os
import gc

# %%
class process_hyperspec(object):
    
    def __init__(self, path, scat):
        self.path = path
        self.scat = scat
        
    def read_data(self):
        ## Read data from txt
        data=pd.read_fwf(self.path, dtype = object, header = None)## Read data as Pandas DataFrame
        data_8 = data.loc[8,:].str[6:] ## Select data of column of wavelengths

        data_nm_dataframe =pd.read_csv(StringIO(data_8[0]))

        with open(self.path,'r',encoding='utf-8') as f:
            content = f.read()

        flag = 0
        for index in range(len(content)):##find the start point  of time and intensity data, pointer is the 'index'
            if (content[index] == '\n') and (flag != 9):
                flag = flag + 1
            elif (content[index] == '\n') and (flag == 9):
                break
            else:
                continue

        data_ns = pd.read_csv(StringIO(content[index:len(content)]), names = data_nm_dataframe.columns[0:len(set(data_nm_dataframe))]) ## Read data of time and gray 
        img_nm_ns = np.array(data_ns)    ## Transform to numpy array                                image as DataFrame; names is a 640x0 array indicates the wavelengths range
        
        self.data_frame = data_ns
        self.data_array = img_nm_ns
        
    def cal_846nm(self):
        time_total, wavelength_total = self.data_array.shape ## Generate an array contains intensity versus time data on 846nm
        data_846nm = np.zeros((time_total,), dtype = float )

        for i in range(wavelength_total):
            data_846nm = self.data_array[:,i] + data_846nm

        return data_846nm/wavelength_total
    
    def return_dataframe(self):
        
        return self.data_frame
    
    def return_array(self):
        return self.data_array

# %%
dict0 = {}
for i in range(1,100):
    dict0[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230210\\常温\\Sample'+str(i)+'.txt'
dict0[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230210\\常温\\irf00.txt'

# %%
files = os.listdir(dict0[0][0:-10])   # 读入文件夹
N = len(files)       # 统计文件夹中的文件个数
scat = [None]*N
data_480multi9 = np.zeros((N,480), dtype = float)
time_index = np.zeros((N,480))
j=0
for i in range(0,100):
    if os.path.exists(dict0[i]):
        scat[j] = process_hyperspec(dict0[i], i)
        scat[j].read_data()
        data_480multi9[j,:] = scat[j].cal_846nm()
        time_index[j] = scat[j].return_dataframe().index
        j=j+1
    else:
        pass
# ##############################################
# str0 = '['
# for i in range(N):
#     str0 = str0 +'line['+str(i)+'],'

# str0 = str0[0:-1]
# str0 = str0+']'
# ###############################################
# #########################################
# str1 = '['
# for i in range(N):
#     str1 = str1 + '\''+eval('dict0')[i][12:-4]+'\''+','

# str1 = str1+']'
# ###############################################
# line = [None]*N
# plt.figure(figsize = (5,5))
# for i in range(0,N):
#     line[i], = plt.plot(time_index[i],data_480multi9[i,:])

# plt.legend(handles=eval(str0)
#            ,labels=eval(str1),loc='best')
# plt.show()

# %%
kernel0 = np.ones((10,))
data_smooth = np.zeros((N-1,480))
for i in range(N-1):
    data_smooth[i] = np.convolve(kernel0,data_480multi9[i+1],'same')/np.sum(kernel0)
y = np.zeros((data_smooth.shape[0],data_smooth.shape[1]*2-1))
y[:,0:data_smooth.shape[1]] = data_smooth
h = np.convolve(kernel0,data_480multi9[0],'same')/np.sum(kernel0)

# %%
##########################################
fig = plt.figure(figsize = (4,4))
# plt.subplot(1,2,2)
# for i in range(1,N):
#     plt.plot(time_index[i]*1e-9,data_480multi9[i])
# plt.subplot(1,2,1)
for i in range(0,y.shape[0]):
    plt.plot(time_index[i]*1e-9,y[i,0:data_smooth.shape[1]])
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)


plt.show()

# %%
##########################################
fig = plt.figure(figsize = (4,4))

plt.plot(time_index[i]*1e-9,h)
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)


plt.show()

# %%
class calculate_miu_s1(object):
    
    def __init__(self, h, y, time_index,d):
        self.h = h
        self.y = y
        self.time = time_index
        self.d = d
        return None
    
    def transmittance(self, d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
    
    def error_cal(self, x):
        miu_a = x[0]
        #miu_a = 69
        miu_s = x[1]
         
        # k = 0.1
        # miu_a = 0.01e2
        g = 0.85
        # d = 0.38e-3
        d = self.d
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = self.time*1e-9
        # miu_s = miu_s*1e4
        intensity1 = np.zeros((T, ), dtype = float)
        for i in range(time.shape[0] ):

            intensity1[i] = calculate_miu_s1.transmittance(self, d, time[i], c, g, miu_a, miu_s)
        
        y2 = np.convolve(intensity1, self.h)
        self.intensity = intensity1
        self.y_convolved = y2
        y2 = y2/max(abs(y2))
        y3 = self.y/max(abs(self.y))
        
        return np.sum(abs(y2 - y3))
#         return time

    def get_convolved_signal(self):
        return self.y_convolved
        
    def get_x(self):
        return self.intensity

# %%
# %%capture --no-display
miu_s_get = np.zeros((y.shape[0],2))
m1=[None]*y.shape[0]
fun_value = np.zeros((y.shape[0],))
d = 50e-3
bnds = ((0, None), (0, None))
for i in range(y.shape[0]):
    m1[i] = calculate_miu_s1(h, y[i], time_index[i+1],d)
    minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
    miu_s_get[i], fun_value[i] = minu.x, minu.fun # Nelder-Mead
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\1424569783.py:9: OptimizeWarning: Unknown solver options: xtol
#   minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# Optimization terminated successfully.
#          Current function value: 23.767307
#          Iterations: 74
#          Function evaluations: 140
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\2646682250.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   Z0 = 1/(miu_s_prime)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\2646682250.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\2646682250.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\2646682250.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\2646682250.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
# Optimization terminated successfully.
#          Current function value: 17.218324
#          Iterations: 82
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 13.599111
#          Iterations: 90
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 16.910319
#          Iterations: 94
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 28.594780
#          Iterations: 131
#          Function evaluations: 253
# Optimization terminated successfully.
#          Current function value: 18.043203
#          Iterations: 76
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 23.440072
#          Iterations: 91
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 16.061877
#          Iterations: 84
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 23.403404
#          Iterations: 100
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 24.944211
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 11.527541
#          Iterations: 76
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 11.010222
#          Iterations: 93
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 27.545354
#          Iterations: 75
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 25.903915
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 24.079228
#          Iterations: 83
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 17.882539
#          Iterations: 85
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 14.890052
#          Iterations: 74
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 19.885259
#          Iterations: 101
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: 25.287372
#          Iterations: 89
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 17.742297
#          Iterations: 108
#          Function evaluations: 211
# Optimization terminated successfully.
#          Current function value: 21.223448
#          Iterations: 93
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 13.113226
#          Iterations: 92
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 14.046664
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 17.875484
#          Iterations: 99
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 54.395164
#          Iterations: 107
#          Function evaluations: 208
# Optimization terminated successfully.
#          Current function value: 16.912136
#          Iterations: 81
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 28.779032
#          Iterations: 99
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 21.323341
#          Iterations: 74
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 11.569775
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 39.013186
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 11.780962
#          Iterations: 93
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 24.190389
#          Iterations: 88
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 14.422605
#          Iterations: 80
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 14.292843
#          Iterations: 74
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 23.168429
#          Iterations: 87
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 17.043867
#          Iterations: 84
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 12.515513
#          Iterations: 95
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 30.229072
#          Iterations: 84
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 21.942438
#          Iterations: 88
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 10.898707
#          Iterations: 117
#          Function evaluations: 220
# Optimization terminated successfully.
#          Current function value: 13.066009
#          Iterations: 105
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 17.225822
#          Iterations: 79
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 21.325676
#          Iterations: 75
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 36.422927
#          Iterations: 104
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 21.189759
#          Iterations: 99
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 13.370475
#          Iterations: 114
#          Function evaluations: 221
# Optimization terminated successfully.
#          Current function value: 35.675073
#          Iterations: 81
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 37.710273
#          Iterations: 69
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 43.401815
#          Iterations: 80
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 17.103399
#          Iterations: 89
#          Function evaluations: 169
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13172\1424569783.py:9: RuntimeWarning: Maximum number of function evaluations has been exceeded.
#   minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# Optimization terminated successfully.
#          Current function value: 31.724523
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 13.034305
#          Iterations: 91
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 26.138394
#          Iterations: 93
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 15.615239
#          Iterations: 80
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 15.017971
#          Iterations: 74
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 29.286018
#          Iterations: 100
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: 13.688876
#          Iterations: 94
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 10.962728
#          Iterations: 82
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 26.158319
#          Iterations: 104
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: 18.926971
#          Iterations: 107
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 14.606267
#          Iterations: 108
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: 22.154591
#          Iterations: 81
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 22.061694
#          Iterations: 77
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 19.027371
#          Iterations: 108
#          Function evaluations: 206
# Optimization terminated successfully.
#          Current function value: 15.112147
#          Iterations: 104
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: 15.905731
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 20.833539
#          Iterations: 85
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 20.437035
#          Iterations: 83
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 22.624785
#          Iterations: 85
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 13.122272
#          Iterations: 86
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 33.406523
#          Iterations: 79
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 10.850532
#          Iterations: 80
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 18.509344
#          Iterations: 89
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 25.355015
#          Iterations: 77
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 20.092978
#          Iterations: 101
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 27.546464
#          Iterations: 80
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 17.353164
#          Iterations: 97
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 18.841536
#          Iterations: 94
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 35.525999
#          Iterations: 95
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 25.949188
#          Iterations: 89
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 15.758754
#          Iterations: 97
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 13.544777
#          Iterations: 72
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 16.302702
#          Iterations: 110
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 35.901093
#          Iterations: 83
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 19.421442
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 30.617318
#          Iterations: 87
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 30.722645
#          Iterations: 122
#          Function evaluations: 239
# Optimization terminated successfully.
#          Current function value: 32.985640
#          Iterations: 98
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 17.149381
#          Iterations: 89
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 18.492651
#          Iterations: 74
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 19.572619
#          Iterations: 80
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 14.317192
#          Iterations: 88
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 14.494567
#          Iterations: 74
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 17.568836
#          Iterations: 90
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 30.414518
#          Iterations: 165
#          Function evaluations: 319
# Optimization terminated successfully.
#          Current function value: 33.694133
#          Iterations: 86
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 17.402108
#          Iterations: 104
#          Function evaluations: 197
# Optimization terminated successfully.
#          Current function value: 45.099259
#          Iterations: 91
#          Function evaluations: 175

# %%
miu_s_get
# Out:
# array([[7.81763177e+00, 2.94331161e+03],
#        [5.44575505e+00, 1.99472054e+03],
#        [8.99393756e+00, 2.62445293e+03],
#        [5.30403319e+00, 2.58404458e+03],
#        [5.74197281e+00, 3.34573814e+03],
#        [8.61867121e+00, 2.53862961e+03],
#        [5.47641826e+00, 2.00928511e+03],
#        [7.06684288e+00, 2.79433478e+03],
#        [6.99550967e+00, 2.97316674e+03],
#        [6.84597749e+00, 3.43280100e+03],
#        [5.52756230e+00, 1.60512122e+03],
#        [7.31011006e+00, 2.09044445e+03],
#        [8.00851761e+00, 3.08718480e+03],
#        [7.01054747e+00, 3.15153639e+03],
#        [8.56629782e+00, 3.13746478e+03],
#        [8.12416235e+00, 2.95073937e+03],
#        [7.33885672e+00, 2.43755913e+03],
#        [7.23105911e+00, 2.23605297e+03],
#        [7.77569064e+00, 2.40795808e+03],
#        [8.89476731e+00, 2.25875390e+03],
#        [7.19829488e+00, 3.38073511e+03],
#        [8.04223896e+00, 2.14316749e+03],
#        [7.83198851e+00, 2.46564701e+03],
#        [8.79590575e+00, 2.72239642e+03],
#        [6.43755756e+00, 2.68216388e+03],
#        [8.25729960e+00, 2.53096098e+03],
#        [7.16785083e+00, 3.03363722e+03],
#        [8.01421856e+00, 2.89645087e+03],
#        [8.44728888e+00, 2.28880981e+03],
#        [5.33041321e+00, 2.63453732e+03],
#        [8.34642387e+00, 2.21398086e+03],
#        [6.68882824e+00, 2.42925308e+03],
#        [5.08993669e+00, 1.80820554e+03],
#        [4.53803708e+00, 2.15211648e+03],
#        [6.29606449e+00, 2.41174993e+03],
#        [7.41367690e+00, 2.60154203e+03],
#        [8.18716301e+00, 2.17891595e+03],
#        [8.00877650e+00, 3.30161210e+03],
#        [7.91122013e+00, 2.69107493e+03],
#        [8.00937800e+00, 2.10984176e+03],
#        [7.81149517e+00, 2.49733945e+03],
#        [8.63390957e+00, 2.67739377e+03],
#        [7.84336379e+00, 2.19038904e+03],
#        [5.63186387e+00, 3.40518973e+03],
#        [8.33568887e+00, 2.56036806e+03],
#        [6.13406723e+00, 2.06834683e+03],
#        [5.57154760e+00, 2.28238553e+03],
#        [7.77660222e+00, 3.68360537e+03],
#        [5.26074769e+00, 3.20369247e+03],
#        [7.07738700e+00, 2.49501451e+03],
#        [7.09751722e+00, 3.20837598e+03],
#        [6.66676419e+00, 2.41220493e+03],
#        [4.45839029e+00, 1.48017693e+03],
#        [6.19369401e+00, 2.91617188e+03],
#        [6.08534214e+00, 2.36642743e+03],
#        [7.94821934e+00, 2.16890186e+03],
#        [7.37004856e+00, 2.69270773e+03],
#        [6.95495298e+00, 2.05619093e+03],
#        [5.97546523e+00, 1.71522504e+03],
#        [8.51494040e+00, 2.24607378e+03],
#        [7.58848321e+00, 2.52023162e+03],
#        [7.11300802e+00, 1.90247222e+03],
#        [5.97330545e+00, 2.24388577e+03],
#        [6.02105391e+00, 2.25514986e+03],
#        [8.20041786e+00, 2.22068167e+03],
#        [7.68162200e+00, 2.14653214e+03],
#        [6.81167178e+00, 2.31352771e+03],
#        [3.75060173e+00, 1.77197670e+03],
#        [6.93990135e+00, 2.88138211e+03],
#        [7.30417096e+00, 2.29015031e+03],
#        [6.27187550e+00, 2.15870730e+03],
#        [7.36299578e+00, 2.68469494e+03],
#        [6.62504710e+00, 1.64134046e+03],
#        [6.82099458e+00, 2.81795797e+03],
#        [7.49918216e+00, 2.64696934e+03],
#        [8.42954907e+00, 2.42035298e+03],
#        [7.77567941e+00, 2.58997348e+03],
#        [8.33217813e+00, 2.64431696e+03],
#        [6.83168016e+00, 2.35088465e+03],
#        [2.78052851e+00, 1.96029986e+03],
#        [7.64285731e+00, 2.41721858e+03],
#        [8.81746450e+00, 2.58856490e+03],
#        [6.69768178e+00, 2.29401398e+03],
#        [7.65480594e+00, 2.52502443e+03],
#        [6.92342269e+00, 2.96841049e+03],
#        [5.72418673e+00, 2.03221099e+03],
#        [6.94555183e+00, 2.62142869e+03],
#        [5.37817782e+00, 2.27233919e+03],
#        [8.85613124e+00, 2.78177998e+03],
#        [5.51217857e+00, 2.31009002e+03],
#        [5.51732806e+00, 1.92856641e+03],
#        [6.84739645e+00, 2.64981501e+03],
#        [8.57006703e+00, 2.18991505e+03],
#        [7.14434791e+00, 2.53284366e+03],
#        [5.54528497e+00, 1.85565742e+03],
#        [6.73099638e+00, 2.86996671e+03],
#        [1.03439467e+01, 3.50967476e+03],
#        [6.91789394e+00, 2.31962254e+03],
#        [6.14689972e+00, 3.09431695e+03]])

# %%
np.sum(miu_s_get[:,1]/miu_s_get.shape[0])
# Out:
# 2503.3255352096025

# %%
np.sum(np.max(y,1))/y.shape[0]
# Out:
# 0.037204861111111105

# %%
# %%capture --no-display
miu = np.zeros((2,2))
miu = np.array([[83.21829252, 9789.38773514],[104.08146906,  9540.58548081]])
m2=[None]*2
d = np.array([1.3,3])*1e-3
yk0 = np.zeros((2,959))
for i in range(2):
    m2[i] = calculate_miu_s1(h[i], y[i], time_index[0],d[i])
    m2[i].error_cal([miu[i,0],miu[i,1]])
    yk0[i] = m2[i].get_convolved_signal()

# %%
print(np.sum(abs(fun_value)))
print(fun_value)
plt.figure(figsize = (18,6))
yk1 = np.zeros((2,959))

for i in range (2):
    yk1[i] = m1[i].get_convolved_signal()

for i in range(2):
    plt.subplot(1,3,i+1)
    plt.plot(y[i,:]/max(abs(y[i,:])),'-.')
    plt.plot(yk1[i]/max(abs(yk1[i])),'-.')
    plt.plot(yk0[i]/max(abs(yk0[i])),'-.')
    
plt.tight_layout(pad=1.0)
plt.show()
# Out:
# 6.232967532058431
# [2.67471907 3.55824846]
