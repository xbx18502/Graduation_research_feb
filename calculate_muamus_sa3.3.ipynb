# %%
# calculate kiwifruit 's each parts' mua, mus, with equal scale enlarge
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# import tensorflow as tf
import math
# from scipy.optimize import fsolve
# from scipy.optimize import root
import scipy as scipy
from scipy.optimize import minimize
# from scipy import signal
# from scipy import linalg
# import scipy as scp
# import sympy as  syp
# from tensorflow.keras import backend as K
# from tensorflow.keras.layers import Layer
# from tensorflow.keras.models import Sequential
import os
import gc

# %%
class process_hyperspec(object):
    
    def __init__(self, path, scat):
        self.path = path
        self.scat = scat
        
    def read_data(self):
        ## Read data from txt
        data=pd.read_fwf(self.path, dtype = object, header = None)## Read data as Pandas DataFrame
        data_8 = data.loc[8,:].str[6:] ## Select data of column of wavelengths

        data_nm_dataframe =pd.read_csv(StringIO(data_8[0]))

        with open(self.path,'r',encoding='utf-8') as f:
            content = f.read()

        flag = 0
        for index in range(len(content)):##find the start point  of time and intensity data, pointer is the 'index'
            if (content[index] == '\n') and (flag != 9):
                flag = flag + 1
            elif (content[index] == '\n') and (flag == 9):
                break
            else:
                continue

        data_ns = pd.read_csv(StringIO(content[index:len(content)]), names = data_nm_dataframe.columns[0:len(set(data_nm_dataframe))]) ## Read data of time and gray 
        img_nm_ns = np.array(data_ns)    ## Transform to numpy array                                image as DataFrame; names is a 640x0 array indicates the wavelengths range
        
        self.data_frame = data_ns
        self.data_array = img_nm_ns
        
    def cal_846nm(self):
        time_total, wavelength_total = self.data_array.shape ## Generate an array contains intensity versus time data on 846nm
        data_846nm = np.zeros((time_total,), dtype = float )

        for i in range(wavelength_total):
            data_846nm = self.data_array[:,i] + data_846nm

        return data_846nm/wavelength_total
    
    def return_dataframe(self):
        
        return self.data_frame
    
    def return_array(self):
        return self.data_array

# %%
dict0 = {}
for i in range(1,100):
    dict0[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230210\\常温\\Sample'+str(i)+'.txt'
dict0[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230210\\常温\\irf00.txt'

dict1 = {}
for i in range(1,100):
    dict1[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230211\\常温\\Sample'+str(i)+'.txt'
dict1[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230211\\常温\\irf00.txt'

dict2 = {}
for i in range(1,100):
    dict2[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230212\\常温\\Sample'+str(i)+'.txt'
dict2[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230212\\常温\\irf00.txt'

dict3 = {}
for i in range(1,100):
    dict3[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230213\\常温\\Sample'+str(i)+'.txt'
dict3[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230213\\常温\\irf00.txt'

dict4 = {}
for i in range(1,100):
    dict4[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230215\\常温\\Sample'+str(i)+'.txt'
dict4[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230215\\常温\\irf00.txt'

dict5 = {}
for i in range(1,100):
    dict5[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230217\\常温\\Sample'+str(i)+'.txt'
dict5[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230217\\常温\\irf00.txt'

dict6 = {}
for i in range(1,100):
    dict6[i] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230218\\常温\\Sample'+str(i)+'.txt'
dict6[0] = 'D:\\files2\\Nagoya\\python\\kiwi_ToF_simulation\\feb\\20230218\\常温\\irf00.txt'
dictn = [dict0,dict1,dict2,dict3,dict4,dict5,dict6]

# %%
class analyze(object):
    def __init__(self):

        return
    def read_radius(self):
        data1 = pd.read_excel('./kiwi_data.xlsx',sheet_name=1,header=None)
        data2 = np.array(data1)
        return data2[:,1]

    def read_everyday(self,dict0,radius):    
        files = os.listdir(dict0[0][0:-10])   # 读入文件夹
        N = len(files)       # 统计文件夹中的文件个数
        scat = [None]*N
        data_480multi9 = np.zeros((N,480), dtype = float)
        time_index = np.zeros((N,480))
        radius0 = np.zeros((N-1,))
        j=0
        for i in range(0,100):
            if os.path.exists(dict0[i]):
                scat[j] = process_hyperspec(dict0[i], i)
                scat[j].read_data()
                data_480multi9[j,:] = scat[j].cal_846nm()
                time_index[j] = scat[j].return_dataframe().index
                if(i!=0):
                    radius0[j-1] = radius[i-1]
                j=j+1
            else:
                pass
        return data_480multi9,time_index,N,radius0

    def generate_h_y(self,data_480multi9,N):
        kernel0 = np.ones((10,))
        data_smooth = np.zeros((N-1,480))
        for i in range(N-1):
            data_smooth[i] = np.convolve(kernel0,data_480multi9[i+1],'same')/np.sum(kernel0)
        y = np.zeros((data_smooth.shape[0],data_smooth.shape[1]*2-1))
        y[:,0:data_smooth.shape[1]] = data_smooth
        h = np.convolve(kernel0,data_480multi9[0],'same')/np.sum(kernel0)
        return h,y

# %%
ana = analyze()
H = []
Y = []
TIME = []
R = []
AMOUNT_EXP = len(dictn)
for i in range(AMOUNT_EXP):
    radius = ana.read_radius()
    data_480multi9,time_index,N,radius0 = ana.read_everyday(dictn[i],radius)
    h,y = ana.generate_h_y(data_480multi9,N)
    H.append(h)
    Y.append(y)
    TIME.append(time_index)
    R.append(radius0)

# %%
##########################################
fig = plt.figure(figsize = (8,8))
for i in range(AMOUNT_EXP):
    plt.subplot(3,4,i+1)
    for j in range(Y[i].shape[0]):
        plt.plot(time_index[i]*1e-9,Y[i][j,0:data_480multi9.shape[1]])
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)

plt.show()

# %%
##########################################
fig = plt.figure(figsize = (4,4))

plt.plot(time_index[i]*1e-9,h)
# plt.title.set_text(dict0[i][9:-4])
fig.tight_layout(pad=1.1)


plt.show()

# %%
class calculate_miu_s1(object):
    
    def __init__(self, h, y, time_index,d):
        self.h = h
        self.y = y
        self.time = time_index
        self.d = d
        return None
    
    def transmittance(self, d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
    
    def error_cal(self, x):
        miu_a = x[0]
        #miu_a = 69
        miu_s = x[1]
         
        # k = 0.1
        # miu_a = 0.01e2
        g = 0.85
        # d = 0.38e-3
        d = self.d
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = self.time*1e-9
        # miu_s = miu_s*1e4
        intensity1 = np.zeros((T, ), dtype = float)
        for i in range(time.shape[0] ):

            intensity1[i] = calculate_miu_s1.transmittance(self, d, time[i], c, g, miu_a, miu_s)
        
        y2 = np.convolve(intensity1, self.h)
        self.intensity = intensity1
        self.y_convolved = y2
        y2 = y2/max(abs(y2))
        y3 = self.y/max(abs(self.y))
        
        return np.sum(abs(y2 - y3))
#         return time

    def get_convolved_signal(self):
        return self.y_convolved
        
    def get_x(self):
        return self.intensity

# %%
class call_cal(object):
    def __init__(self):
        return
    def call_cal(self,h,y,time_index,radius):
            # %%capture --no-display
            miu_s_get = np.zeros((y.shape[0],2))
            m1=[None]*y.shape[0]
            fun_value = np.zeros((y.shape[0],))
            bnds = ((0, None), (0, None))
            for i in range(y.shape[0]):
                d = radius[i]*1e-3
                m1[i] = calculate_miu_s1(h, y[i], time_index[i+1],d)
                minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
                miu_s_get[i], fun_value[i] = minu.x, minu.fun # Nelder-Mead
            return miu_s_get

    def call_(self,H,Y,TIME,R,AMOUNT_EXP):
        miu_as = []
        for i in range(AMOUNT_EXP):
            miu_s_get = self.call_cal(H[i],Y[i],TIME[i],R[i])
            miu_as.append(miu_s_get)
        return miu_as

# %%
call = call_cal()
miu_as = call.call_(H,Y,TIME,R,AMOUNT_EXP)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14028\1489176112.py:13: OptimizeWarning: Unknown solver options: xtol
#   minu = minimize(m1[i].error_cal, x0 = [0.1e2,100e2], method  = 'Nelder-Mead', bounds = bnds, options={"xtol" : 1e-20, "disp":True})
# Optimization terminated successfully.
#          Current function value: 23.767277
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 17.213433
#          Iterations: 70
#          Function evaluations: 138
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14028\3771615487.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   Z0 = 1/(miu_s_prime)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14028\3771615487.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14028\3771615487.py:17: RuntimeWarning: invalid value encountered in double_scalars
#   h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14028\3771615487.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14028\3771615487.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
# Optimization terminated successfully.
#          Current function value: 13.600060
#          Iterations: 89
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 16.909628
#          Iterations: 85
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 28.595246
#          Iterations: 138
#          Function evaluations: 270
# Optimization terminated successfully.
#          Current function value: 18.042274
#          Iterations: 78
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 23.431560
#          Iterations: 93
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 16.059258
#          Iterations: 80
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 23.406164
#          Iterations: 104
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 24.942776
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 11.539034
#          Iterations: 74
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 11.011439
#          Iterations: 80
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 27.545665
#          Iterations: 79
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 25.905071
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 24.078722
#          Iterations: 77
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 17.882963
#          Iterations: 74
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 14.890984
#          Iterations: 85
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 19.892234
#          Iterations: 82
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 25.287491
#          Iterations: 109
#          Function evaluations: 209
# Optimization terminated successfully.
#          Current function value: 17.745624
#          Iterations: 74
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 21.222834
#          Iterations: 81
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 13.114633
#          Iterations: 96
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 14.048323
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 17.874130
#          Iterations: 84
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 54.393476
#          Iterations: 81
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 16.917385
#          Iterations: 84
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 28.777266
#          Iterations: 109
#          Function evaluations: 206
# Optimization terminated successfully.
#          Current function value: 21.321574
#          Iterations: 73
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 11.572257
#          Iterations: 84
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 39.020510
#          Iterations: 71
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 11.783242
#          Iterations: 90
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 24.190785
#          Iterations: 75
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 14.429793
#          Iterations: 73
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 14.299157
#          Iterations: 93
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 23.171554
#          Iterations: 86
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 17.042883
#          Iterations: 79
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 12.514702
#          Iterations: 89
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 30.227795
#          Iterations: 79
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 21.942359
#          Iterations: 112
#          Function evaluations: 220
# Optimization terminated successfully.
#          Current function value: 10.905983
#          Iterations: 69
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 13.067032
#          Iterations: 87
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 17.221977
#          Iterations: 87
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 21.320908
#          Iterations: 71
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 36.423054
#          Iterations: 83
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 21.187195
#          Iterations: 87
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 13.371576
#          Iterations: 107
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: 35.676706
#          Iterations: 85
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 37.710928
#          Iterations: 73
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 43.402761
#          Iterations: 77
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 17.105197
#          Iterations: 99
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 24.629829
#          Iterations: 89
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 31.724279
#          Iterations: 88
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 13.058632
#          Iterations: 90
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 26.139878
#          Iterations: 102
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 15.618611
#          Iterations: 103
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 15.013750
#          Iterations: 95
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 29.284166
#          Iterations: 120
#          Function evaluations: 233
# Optimization terminated successfully.
#          Current function value: 13.696960
#          Iterations: 90
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 10.962120
#          Iterations: 99
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 26.149971
#          Iterations: 90
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 18.926991
#          Iterations: 83
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 14.604067
#          Iterations: 117
#          Function evaluations: 223
# Optimization terminated successfully.
#          Current function value: 22.154795
#          Iterations: 89
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 22.065186
#          Iterations: 74
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 19.028784
#          Iterations: 99
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 15.109327
#          Iterations: 99
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 15.906041
#          Iterations: 83
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 20.831775
#          Iterations: 80
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 20.436258
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 22.613552
#          Iterations: 84
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 13.133844
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 33.404704
#          Iterations: 108
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 10.861226
#          Iterations: 77
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 18.508989
#          Iterations: 94
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 25.354990
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 20.090873
#          Iterations: 110
#          Function evaluations: 212
# Optimization terminated successfully.
#          Current function value: 27.545574
#          Iterations: 84
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 17.353162
#          Iterations: 93
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 18.839218
#          Iterations: 94
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 35.524699
#          Iterations: 104
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 25.947897
#          Iterations: 81
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 15.758168
#          Iterations: 92
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 13.544152
#          Iterations: 74
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 16.304122
#          Iterations: 86
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 35.900673
#          Iterations: 76
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 19.419286
#          Iterations: 80
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 30.617644
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 30.720434
#          Iterations: 92
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 32.985759
#          Iterations: 84
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 17.150149
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 18.501274
#          Iterations: 98
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 19.574178
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 14.332579
#          Iterations: 85
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 14.494441
#          Iterations: 75
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 17.573131
#          Iterations: 73
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 30.414788
#          Iterations: 99
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 33.691389
#          Iterations: 83
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 17.403805
#          Iterations: 87
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 45.102744
#          Iterations: 118
#          Function evaluations: 231
# Optimization terminated successfully.
#          Current function value: 12.294743
#          Iterations: 119
#          Function evaluations: 232
# Optimization terminated successfully.
#          Current function value: 26.688187
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 32.811568
#          Iterations: 91
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 21.306578
#          Iterations: 75
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 13.357166
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 12.348645
#          Iterations: 79
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 19.815754
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 22.281311
#          Iterations: 76
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 20.816198
#          Iterations: 108
#          Function evaluations: 211
# Optimization terminated successfully.
#          Current function value: 13.089897
#          Iterations: 99
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 16.085549
#          Iterations: 89
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 15.368675
#          Iterations: 93
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 26.918677
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 15.262745
#          Iterations: 106
#          Function evaluations: 206
# Optimization terminated successfully.
#          Current function value: 28.563526
#          Iterations: 85
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 20.444464
#          Iterations: 101
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 12.844302
#          Iterations: 88
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 27.241874
#          Iterations: 88
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 16.339187
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 20.326707
#          Iterations: 88
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 14.884672
#          Iterations: 103
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 16.918425
#          Iterations: 92
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 16.288311
#          Iterations: 97
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 16.631325
#          Iterations: 96
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 14.521148
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 24.885709
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 17.521295
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 15.807474
#          Iterations: 80
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 12.826245
#          Iterations: 87
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 16.690687
#          Iterations: 92
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 16.381696
#          Iterations: 77
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 35.254803
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 16.322398
#          Iterations: 70
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 17.176604
#          Iterations: 83
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 25.162592
#          Iterations: 83
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 30.386934
#          Iterations: 85
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 32.708189
#          Iterations: 75
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 19.837218
#          Iterations: 70
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 21.516965
#          Iterations: 91
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 27.252938
#          Iterations: 153
#          Function evaluations: 303
# Optimization terminated successfully.
#          Current function value: 11.294481
#          Iterations: 80
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 20.150721
#          Iterations: 91
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 14.416193
#          Iterations: 95
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 13.495287
#          Iterations: 106
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 23.911387
#          Iterations: 84
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 15.821452
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 14.073614
#          Iterations: 107
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 27.492319
#          Iterations: 83
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 24.222535
#          Iterations: 135
#          Function evaluations: 264
# Optimization terminated successfully.
#          Current function value: 17.369875
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 21.240972
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 13.836448
#          Iterations: 113
#          Function evaluations: 222
# Optimization terminated successfully.
#          Current function value: 13.494009
#          Iterations: 105
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: 17.525873
#          Iterations: 78
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 18.945239
#          Iterations: 81
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 24.623068
#          Iterations: 82
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 23.876239
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 22.224500
#          Iterations: 74
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 14.307828
#          Iterations: 96
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 13.791695
#          Iterations: 86
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 13.700795
#          Iterations: 76
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 17.949132
#          Iterations: 94
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 19.318197
#          Iterations: 73
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 22.996476
#          Iterations: 76
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 24.732651
#          Iterations: 80
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 23.618543
#          Iterations: 90
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 15.639917
#          Iterations: 88
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 21.871937
#          Iterations: 89
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 19.352470
#          Iterations: 97
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 15.943387
#          Iterations: 93
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 14.343676
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 12.261223
#          Iterations: 91
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 30.652539
#          Iterations: 106
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 20.566906
#          Iterations: 130
#          Function evaluations: 247
# Optimization terminated successfully.
#          Current function value: 26.973440
#          Iterations: 90
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 21.579888
#          Iterations: 77
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 32.342694
#          Iterations: 129
#          Function evaluations: 250
# Optimization terminated successfully.
#          Current function value: 20.075839
#          Iterations: 102
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: 13.335883
#          Iterations: 107
#          Function evaluations: 205
# Optimization terminated successfully.
#          Current function value: 24.519540
#          Iterations: 71
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 11.320337
#          Iterations: 119
#          Function evaluations: 234
# Optimization terminated successfully.
#          Current function value: 17.109124
#          Iterations: 68
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 13.921824
#          Iterations: 100
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 29.148532
#          Iterations: 105
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: 31.164119
#          Iterations: 80
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 14.765056
#          Iterations: 83
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 38.914920
#          Iterations: 101
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 30.817723
#          Iterations: 99
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 12.936741
#          Iterations: 77
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 19.243354
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 17.518206
#          Iterations: 75
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 28.682887
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 14.664778
#          Iterations: 92
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 13.785003
#          Iterations: 141
#          Function evaluations: 278
# Optimization terminated successfully.
#          Current function value: 12.975454
#          Iterations: 72
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 17.299923
#          Iterations: 86
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 40.565708
#          Iterations: 121
#          Function evaluations: 237
# Optimization terminated successfully.
#          Current function value: 15.149945
#          Iterations: 93
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 33.175497
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 21.690919
#          Iterations: 77
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 12.023693
#          Iterations: 84
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 39.442816
#          Iterations: 94
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 12.237624
#          Iterations: 92
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 23.221675
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 11.334976
#          Iterations: 72
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 12.102125
#          Iterations: 97
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 18.384797
#          Iterations: 69
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 18.914118
#          Iterations: 92
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 15.100611
#          Iterations: 81
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 33.561629
#          Iterations: 99
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 25.812538
#          Iterations: 113
#          Function evaluations: 213
# Optimization terminated successfully.
#          Current function value: 10.960684
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 12.682720
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 20.509247
#          Iterations: 96
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 15.936364
#          Iterations: 87
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 37.741321
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 17.693746
#          Iterations: 86
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 13.603335
#          Iterations: 90
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 29.907225
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 31.974530
#          Iterations: 83
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 47.421007
#          Iterations: 97
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 16.319042
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 34.588432
#          Iterations: 84
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 34.151492
#          Iterations: 71
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 11.165485
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 22.418878
#          Iterations: 74
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 12.814806
#          Iterations: 88
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 12.096856
#          Iterations: 100
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 22.103749
#          Iterations: 81
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 14.895009
#          Iterations: 121
#          Function evaluations: 230
# Optimization terminated successfully.
#          Current function value: 11.463691
#          Iterations: 79
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 22.799754
#          Iterations: 89
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 19.240554
#          Iterations: 95
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 13.481418
#          Iterations: 97
#          Function evaluations: 190
# Optimization terminated successfully.
#          Current function value: 23.874284
#          Iterations: 98
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 14.750390
#          Iterations: 95
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 20.778355
#          Iterations: 88
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 12.857989
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 14.434589
#          Iterations: 99
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 28.805169
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 20.396616
#          Iterations: 114
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 18.194778
#          Iterations: 109
#          Function evaluations: 215
# Optimization terminated successfully.
#          Current function value: 15.397634
#          Iterations: 89
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 17.153792
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 11.531168
#          Iterations: 113
#          Function evaluations: 211
# Optimization terminated successfully.
#          Current function value: 22.390141
#          Iterations: 83
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 19.127950
#          Iterations: 78
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 17.119653
#          Iterations: 82
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 31.381292
#          Iterations: 85
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 17.279760
#          Iterations: 86
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 17.772200
#          Iterations: 83
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 20.863525
#          Iterations: 90
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 19.454159
#          Iterations: 77
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 16.590995
#          Iterations: 74
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 13.953517
#          Iterations: 75
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 16.599533
#          Iterations: 99
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 28.654751
#          Iterations: 83
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 20.920501
#          Iterations: 87
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 27.421994
#          Iterations: 94
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 24.229462
#          Iterations: 95
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 27.469085
#          Iterations: 85
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 14.514415
#          Iterations: 82
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 13.186680
#          Iterations: 88
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 31.434131
#          Iterations: 71
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 15.745844
#          Iterations: 76
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 15.857959
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 13.595596
#          Iterations: 142
#          Function evaluations: 277
# Optimization terminated successfully.
#          Current function value: 40.955537
#          Iterations: 81
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 38.419291
#          Iterations: 98
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 21.660402
#          Iterations: 77
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 38.523060
#          Iterations: 83
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 17.736333
#          Iterations: 92
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 24.930375
#          Iterations: 81
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 15.649138
#          Iterations: 95
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 14.135795
#          Iterations: 85
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 16.255478
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 15.367314
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 30.789026
#          Iterations: 87
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 20.035666
#          Iterations: 90
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 25.652885
#          Iterations: 84
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 18.802841
#          Iterations: 84
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 11.131249
#          Iterations: 104
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 23.550449
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 13.074547
#          Iterations: 87
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 22.990428
#          Iterations: 83
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 14.792367
#          Iterations: 83
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 13.980933
#          Iterations: 80
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 17.027172
#          Iterations: 75
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 13.264362
#          Iterations: 79
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 15.271398
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 35.005064
#          Iterations: 85
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 16.863917
#          Iterations: 80
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 13.109690
#          Iterations: 103
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 13.903527
#          Iterations: 93
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 21.771924
#          Iterations: 80
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 19.637718
#          Iterations: 90
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 44.152680
#          Iterations: 89
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 23.365713
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 14.333163
#          Iterations: 97
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 26.244548
#          Iterations: 98
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 30.314323
#          Iterations: 92
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 40.908450
#          Iterations: 97
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 16.100096
#          Iterations: 87
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 29.206046
#          Iterations: 91
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 26.951037
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 14.403244
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 27.667021
#          Iterations: 93
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 13.586817
#          Iterations: 93
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 14.799554
#          Iterations: 94
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 26.415781
#          Iterations: 93
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 16.117796
#          Iterations: 94
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 11.606485
#          Iterations: 80
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 22.419772
#          Iterations: 110
#          Function evaluations: 210
# Optimization terminated successfully.
#          Current function value: 36.635870
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 16.895116
#          Iterations: 83
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 21.977722
#          Iterations: 96
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 14.112742
#          Iterations: 95
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: 12.795070
#          Iterations: 77
#          Function evaluations: 149
# Optimization terminated successfully.
#          Current function value: 13.247438
#          Iterations: 90
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 13.987287
#          Iterations: 90
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 17.851536
#          Iterations: 85
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 17.232191
#          Iterations: 72
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 15.101648
#          Iterations: 91
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 12.266619
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 16.847806
#          Iterations: 95
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 12.005703
#          Iterations: 85
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 17.023785
#          Iterations: 102
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: 19.893564
#          Iterations: 77
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 16.203079
#          Iterations: 82
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 24.001640
#          Iterations: 90
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 17.572175
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 32.473068
#          Iterations: 84
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 17.120841
#          Iterations: 80
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 20.314936
#          Iterations: 91
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 17.887493
#          Iterations: 80
#          Function evaluations: 150
# ...
# Optimization terminated successfully.
#          Current function value: 17.253567
#          Iterations: 98
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 13.717430
#          Iterations: 92
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 30.123921
#          Iterations: 73
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 12.795796
#          Iterations: 82
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 12.197374
#          Iterations: 92
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 13.757899
#          Iterations: 88
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 14.729676
#          Iterations: 96
#          Function evaluations: 188
# Optimization terminated successfully.
#          Current function value: 20.827829
#          Iterations: 72
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 18.905489
#          Iterations: 88
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 16.947168
#          Iterations: 95
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: 12.031254
#          Iterations: 87
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 16.831726
#          Iterations: 74
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 11.075177
#          Iterations: 99
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 20.262357
#          Iterations: 97
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 20.934798
#          Iterations: 75
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 17.488093
#          Iterations: 88
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 19.022308
#          Iterations: 102
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: 14.542748
#          Iterations: 92
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 13.716987
#          Iterations: 104
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: 16.160609
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 15.557379
#          Iterations: 76
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 15.773767
#          Iterations: 96
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 14.073505
#          Iterations: 104
#          Function evaluations: 198
# Optimization terminated successfully.
#          Current function value: 16.442521
#          Iterations: 76
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 38.041563
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 18.311774
#          Iterations: 96
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 21.078820
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 20.061768
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 27.492622
#          Iterations: 73
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 17.444177
#          Iterations: 100
#          Function evaluations: 194
# Optimization terminated successfully.
#          Current function value: 15.397061
#          Iterations: 82
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 21.647750
#          Iterations: 128
#          Function evaluations: 239
# Optimization terminated successfully.
#          Current function value: 13.698805
#          Iterations: 95
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 15.930226
#          Iterations: 104
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: 14.700682
#          Iterations: 94
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 25.016895
#          Iterations: 74
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 24.863713
#          Iterations: 96
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 18.225636
#          Iterations: 97
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 33.053427
#          Iterations: 81
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 33.564516
#          Iterations: 81
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 13.593633
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 31.144194
#          Iterations: 88
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 18.718417
#          Iterations: 88
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 13.096358
#          Iterations: 75
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 30.295029
#          Iterations: 88
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 10.551146
#          Iterations: 82
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 22.031627
#          Iterations: 73
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 12.823849
#          Iterations: 100
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 12.006369
#          Iterations: 90
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 11.741881
#          Iterations: 88
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 11.625696
#          Iterations: 78
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 10.373167
#          Iterations: 81
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 26.681202
#          Iterations: 90
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 16.442593
#          Iterations: 72
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 11.001000
#          Iterations: 104
#          Function evaluations: 200
# Optimization terminated successfully.
#          Current function value: 13.974160
#          Iterations: 80
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 14.365046
#          Iterations: 85
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 13.928322
#          Iterations: 85
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 38.715501
#          Iterations: 73
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 15.495368
#          Iterations: 94
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 11.187251
#          Iterations: 74
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 22.249080
#          Iterations: 87
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 28.136663
#          Iterations: 90
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 40.314388
#          Iterations: 83
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 15.101762
#          Iterations: 98
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 21.117514
#          Iterations: 84
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 26.757869
#          Iterations: 93
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 9.899613
#          Iterations: 97
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 23.329499
#          Iterations: 86
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 11.539342
#          Iterations: 85
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 10.038417
#          Iterations: 94
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 18.676512
#          Iterations: 74
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 12.904249
#          Iterations: 78
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 9.286054
#          Iterations: 81
#          Function evaluations: 150
# Optimization terminated successfully.
#          Current function value: 21.671632
#          Iterations: 100
#          Function evaluations: 192
# Optimization terminated successfully.
#          Current function value: 37.508685
#          Iterations: 80
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 14.845566
#          Iterations: 74
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 23.670640
#          Iterations: 97
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 11.110064
#          Iterations: 103
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: 15.893019
#          Iterations: 87
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 14.962105
#          Iterations: 105
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 21.308670
#          Iterations: 89
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 19.631311
#          Iterations: 86
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 20.821725
#          Iterations: 81
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 31.188929
#          Iterations: 79
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 13.363727
#          Iterations: 84
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 25.459645
#          Iterations: 86
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 9.296071
#          Iterations: 80
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 23.372085
#          Iterations: 73
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 23.465322
#          Iterations: 88
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 15.698834
#          Iterations: 96
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 28.568778
#          Iterations: 82
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 13.017729
#          Iterations: 92
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 14.302473
#          Iterations: 97
#          Function evaluations: 183
# Optimization terminated successfully.
#          Current function value: 17.318600
#          Iterations: 89
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 16.779279
#          Iterations: 92
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 24.270839
#          Iterations: 86
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 10.506669
#          Iterations: 90
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 17.530383
#          Iterations: 85
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 24.064625
#          Iterations: 83
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 20.952131
#          Iterations: 99
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: 26.194796
#          Iterations: 92
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 20.431089
#          Iterations: 78
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 29.924761
#          Iterations: 96
#          Function evaluations: 182
# Optimization terminated successfully.
#          Current function value: 16.822562
#          Iterations: 95
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 12.753326
#          Iterations: 83
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 26.369251
#          Iterations: 89
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 12.193086
#          Iterations: 79
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 19.101020
#          Iterations: 75
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 14.698367
#          Iterations: 79
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 25.352970
#          Iterations: 88
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: 29.593962
#          Iterations: 113
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 15.052840
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 31.181850
#          Iterations: 120
#          Function evaluations: 235

# %%
avg_miu = [None]*AMOUNT_EXP
for i in range(AMOUNT_EXP):
    avg_miu[i] = np.sum(miu_as[i],axis=0)/Y[i].shape[0]

# %%
avg_miu = [None]*AMOUNT_EXP
miu_as_last70 = [None]*AMOUNT_EXP
for i in range(AMOUNT_EXP):
    miu_as_last70[i] = miu_as[i][-70:-1,:]
    avg_miu[i] = np.sum(miu_as_last70[i],axis=0)/miu_as_last70[i].shape[0]

# %%
avg_miu
# Out:
# [array([   6.90648925, 2644.4678748 ]),
#  array([   8.24452472, 2759.18511511]),
#  array([   7.05729673, 2676.19699048]),
#  array([   5.23940733, 2122.76522285]),
#  array([   5.98707969, 2468.15934333]),
#  array([   7.12443884, 2581.35609818]),
#  array([   6.07437231, 2512.54823366])]

# %%
mua = []
for i in range(len(avg_miu)):
    mua.append(avg_miu[i][0])
mus = []
for i in range(len(avg_miu)):
    mus.append(avg_miu[i][1])
plt.figure(figsize = (8,4))
ax0=plt.subplot(1,2,1)
ax0.set_title('mua')
ax0.set_xticks([0,1,2,3,5,7,8])
ax0.plot([0,1,2,3,5,7,8],mua)
ax1=plt.subplot(1,2,2)
ax1.set_title('mus')
ax1.set_xticks([0,1,2,3,5,7,8])
ax1.plot([0,1,2,3,5,7,8],mus)
plt.show()

# %%
# %%capture --no-display
miu = np.zeros((2,2))
miu = np.array([[83.21829252, 9789.38773514],[104.08146906,  9540.58548081]])
m2=[None]*2
d = np.array([1.3,3])*1e-3
yk0 = np.zeros((2,959))
for i in range(2):
    m2[i] = calculate_miu_s1(h[i], y[i], time_index[0],d[i])
    m2[i].error_cal([miu[i,0],miu[i,1]])
    yk0[i] = m2[i].get_convolved_signal()

# %%
print(np.sum(abs(fun_value)))
print(fun_value)
plt.figure(figsize = (18,6))
yk1 = np.zeros((2,959))

for i in range (2):
    yk1[i] = m1[i].get_convolved_signal()

for i in range(2):
    plt.subplot(1,3,i+1)
    plt.plot(y[i,:]/max(abs(y[i,:])),'-.')
    plt.plot(yk1[i]/max(abs(yk1[i])),'-.')
    plt.plot(yk0[i]/max(abs(yk0[i])),'-.')
    
plt.tight_layout(pad=1.0)
plt.show()
# Out:
# 6.232967532058431
# [2.67471907 3.55824846]
